# %% [markdown]
# # inputs

# %%
algo= input('enter something: ')
# Out:
# enter something: eqfe

# %%
algo
# Out:
# 'eqfe'

# %%
shoe_size = int(input('mete tu numero: '))
# Out:
# mete tu numero: 34

# %%
algo2= input('enter something: ').lower()
# Out:
# enter something: sdfdf

# %%
algo3= input('enter something: ').lstrip().lower()
algo3
# Out:
# enter something: dsogf ofods fjf
# 'dsogf ofods fjf'

# %% [markdown]
# ## exception handling

# %%
try:
    shoe_size =  int(input('mete tu numero: '))
    print(shoe_size)
    
except ValueError:
    print('this is not a number try again...')
# Out:
# mete tu numero: 3rfwf42
# this is not a number try again...

# %%
if len(input('enter a song: '))<2:
    print('input to short')
# Out:
# enter a song:
# input to short

# %% [markdown]
# ## is this in a list

# %%
# python fuzzy matching library
# IMPORTANT

# %%
guests_list=['sian', 'andy','miguel']

# %%
yourname=input('tell name ')
# Out:
# tell name Pau

# %%
if yourname in guests_list:
    print('welcome, you are on the list')
else:
    print('your name is not down and you are not coming in')
# Out:
# your name is not down and you are not coming in

# %% [markdown]
# # APIs

# %%
import json
import requests

# %%
google = requests.get('https://developers.google.com')
print('Google:', google.status_code)

NBA = requests.get('https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason')
print('NBA:', NBA.status_code)

rotten_tomato = requests.get('http://api.rottentomatoes.com/api/public/v1.0/lists/movies/box_office.json')
print('Rotten Tomatoes:', rotten_tomato.status_code)
# Out:
# Google: 200
# NBA: 401
# Rotten Tomatoes: 403

# %% [markdown]
# ## github api

# %% [raw]
# soup=BeautifulSoup(response.content, 'html.parser')

# %% [raw]
# print(soup.prettify())

# %%
github_response = requests.get('https://api.github.com/users/PauPerL/events/public')
github_response.status_code
# Out:
# 200

# %%
github_response.json()
# Out:
# [{'id': '21951900136',
#   'type': 'PushEvent',
#   'actor': {'id': 101154968,
#    'login': 'PauPerL',
#    'display_login': 'PauPerL',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PauPerL',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101154968?'},
#   'repo': {'id': 480380078,
#    'name': 'PauPerL/IronPau',
#    'url': 'https://api.github.com/repos/PauPerL/IronPau'},
#   'payload': {'push_id': 9966412882,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '2ba4d1cf5939e710ac6bd500c778b1eea308cbde',
#    'before': '5cc206f9e73420f016c67e57b7e496e01131adb6',
#    'commits': [{'sha': '2ba4d1cf5939e710ac6bd500c778b1eea308cbde',
#      'author': {'email': '101154968+PauPerL@users.noreply.github.com',
#       'name': 'PauPerL'},
#      'message': 'los ignores a csv gordos\n\nhe tenido que hacer ignore a ciertos csv porque eran muy pesados',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PauPerL/IronPau/commits/2ba4d1cf5939e710ac6bd500c778b1eea308cbde'}]},
#   'public': True,
#   'created_at': '2022-05-24T08:40:17Z'},
#  {'id': '21951857184',
#   'type': 'PushEvent',
#   'actor': {'id': 101154968,
#    'login': 'PauPerL',
#    'display_login': 'PauPerL',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PauPerL',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101154968?'},
#   'repo': {'id': 480380078,
#    'name': 'PauPerL/IronPau',
#    'url': 'https://api.github.com/repos/PauPerL/IronPau'},
#   'payload': {'push_id': 9966392718,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '5cc206f9e73420f016c67e57b7e496e01131adb6',
#    'before': '348571ca9a9db72d6bdaad0c3387c9a51fbc44c5',
#    'commits': [{'sha': '5cc206f9e73420f016c67e57b7e496e01131adb6',
#      'author': {'email': '101154968+PauPerL@users.noreply.github.com',
#       'name': 'PauPerL'},
#      'message': 'lots of thing from w7d2\n\nIdk what is here i dont remember when was the last push but today we are at w7d2 first scraping lab',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PauPerL/IronPau/commits/5cc206f9e73420f016c67e57b7e496e01131adb6'}]},
#   'public': True,
#   'created_at': '2022-05-24T08:38:13Z'},
#  {'id': '21900153692',
#   'type': 'PushEvent',
#   'actor': {'id': 101154968,
#    'login': 'PauPerL',
#    'display_login': 'PauPerL',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PauPerL',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101154968?'},
#   'repo': {'id': 480380078,
#    'name': 'PauPerL/IronPau',
#    'url': 'https://api.github.com/repos/PauPerL/IronPau'},
#   'payload': {'push_id': 9938448242,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '348571ca9a9db72d6bdaad0c3387c9a51fbc44c5',
#    'before': 'd10161a4ede9ec7050f04e83b061d0f09d36bd54',
#    'commits': [{'sha': '348571ca9a9db72d6bdaad0c3387c9a51fbc44c5',
#      'author': {'email': '101154968+PauPerL@users.noreply.github.com',
#       'name': 'PauPerL'},
#      'message': 'Mega push desde micampw5 a w6\n\nUn mega push que tiene montones de cosas ya que creo que estoy pusheando cosas que van desde el proyecto midcamp ha cosas de la semana que estuve enfermo w6',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PauPerL/IronPau/commits/348571ca9a9db72d6bdaad0c3387c9a51fbc44c5'}]},
#   'public': True,
#   'created_at': '2022-05-20T12:40:42Z'},
#  {'id': '21807893820',
#   'type': 'PushEvent',
#   'actor': {'id': 101154968,
#    'login': 'PauPerL',
#    'display_login': 'PauPerL',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PauPerL',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101154968?'},
#   'repo': {'id': 488233830,
#    'name': 'PauPerL/BCNDATA2022',
#    'url': 'https://api.github.com/repos/PauPerL/BCNDATA2022'},
#   'payload': {'push_id': 9893476400,
#    'size': 8,
#    'distinct_size': 8,
#    'ref': 'refs/heads/main',
#    'head': 'fd35099aaa6bc1913262e6be3d91a61277d21b94',
#    'before': 'c5e207df710d3b445b48df4757608fc6d04af00c',
#    'commits': [{'sha': 'ea807f74bbd67bb865856e837b960bc9f5c5236c',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'Create fri_6_may.ipynb',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/commits/ea807f74bbd67bb865856e837b960bc9f5c5236c'},
#     {'sha': '79bc6bc74ce60383260e639e59c10c1a89aaddd2',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'Create abTesting.xlsx',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/commits/79bc6bc74ce60383260e639e59c10c1a89aaddd2'},
#     {'sha': 'bfabaab502edb4f67e696edebade1b7e48875d6c',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'move around data for week 6 classes',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/commits/bfabaab502edb4f67e696edebade1b7e48875d6c'},
#     {'sha': 'd860d12fe393274daae88bbafbfeee404204bec5',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'update data sources week 6',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/commits/d860d12fe393274daae88bbafbfeee404204bec5'},
#     {'sha': 'fec9142fb2f13c7cfe5c5e7d2445a59d939dc63d',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Update Databricks_intro.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/commits/fec9142fb2f13c7cfe5c5e7d2445a59d939dc63d'},
#     {'sha': '15e27b2ecb73df710a567f34dd3c2ba715600dc8',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'update case study',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/commits/15e27b2ecb73df710a567f34dd3c2ba715600dc8'},
#     {'sha': 'af3fb301741793d1d481f1f6a91213c72c678dde',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'Create stats_16_May_22.ipynb',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/commits/af3fb301741793d1d481f1f6a91213c72c678dde'},
#     {'sha': 'fd35099aaa6bc1913262e6be3d91a61277d21b94',
#      'author': {'email': '71644535+siandav@users.noreply.github.com',
#       'name': 'sian d'},
#      'message': 'Create readme.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/commits/fd35099aaa6bc1913262e6be3d91a61277d21b94'}]},
#   'public': True,
#   'created_at': '2022-05-16T12:07:19Z'},
#  {'id': '21770086046',
#   'type': 'PushEvent',
#   'actor': {'id': 101154968,
#    'login': 'PauPerL',
#    'display_login': 'PauPerL',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PauPerL',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101154968?'},
#   'repo': {'id': 491779671,
#    'name': 'PauPerL/Midcamp_project',
#    'url': 'https://api.github.com/repos/PauPerL/Midcamp_project'},
#   'payload': {'push_id': 9872551334,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '214e0fe939dcae7ab3cc2005d5e1d55f4b155a6c',
#    'before': '32208efea2ac86cc5d3a845adac1ac7df8cac255',
#    'commits': [{'sha': '214e0fe939dcae7ab3cc2005d5e1d55f4b155a6c',
#      'author': {'email': '101154968+PauPerL@users.noreply.github.com',
#       'name': 'PauPerL'},
#      'message': 'more images',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PauPerL/Midcamp_project/commits/214e0fe939dcae7ab3cc2005d5e1d55f4b155a6c'}]},
#   'public': True,
#   'created_at': '2022-05-13T08:12:54Z'},
#  {'id': '21769709223',
#   'type': 'PushEvent',
#   'actor': {'id': 101154968,
#    'login': 'PauPerL',
#    'display_login': 'PauPerL',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PauPerL',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101154968?'},
#   'repo': {'id': 491779671,
#    'name': 'PauPerL/Midcamp_project',
#    'url': 'https://api.github.com/repos/PauPerL/Midcamp_project'},
#   'payload': {'push_id': 9872364775,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '32208efea2ac86cc5d3a845adac1ac7df8cac255',
#    'before': '00e4363d16a303939ff4256e3a78d117195b3a03',
#    'commits': [{'sha': '32208efea2ac86cc5d3a845adac1ac7df8cac255',
#      'author': {'email': '101154968+PauPerL@users.noreply.github.com',
#       'name': 'PauPerL'},
#      'message': 'Imagenes para las slides',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PauPerL/Midcamp_project/commits/32208efea2ac86cc5d3a845adac1ac7df8cac255'}]},
#   'public': True,
#   'created_at': '2022-05-13T07:50:37Z'},
#  {'id': '21768975038',
#   'type': 'PushEvent',
#   'actor': {'id': 101154968,
#    'login': 'PauPerL',
#    'display_login': 'PauPerL',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PauPerL',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101154968?'},
#   'repo': {'id': 491779671,
#    'name': 'PauPerL/Midcamp_project',
#    'url': 'https://api.github.com/repos/PauPerL/Midcamp_project'},
#   'payload': {'push_id': 9871999126,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '00e4363d16a303939ff4256e3a78d117195b3a03',
#    'before': 'e1a0548887824c59634ab20d62b78329ac678790',
#    'commits': [{'sha': '00e4363d16a303939ff4256e3a78d117195b3a03',
#      'author': {'email': '101154968+PauPerL@users.noreply.github.com',
#       'name': 'PauPerL'},
#      'message': 'First readme\n\nFirst readme commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PauPerL/Midcamp_project/commits/00e4363d16a303939ff4256e3a78d117195b3a03'}]},
#   'public': True,
#   'created_at': '2022-05-13T07:03:37Z'},
#  {'id': '21768478912',
#   'type': 'ForkEvent',
#   'actor': {'id': 101154968,
#    'login': 'PauPerL',
#    'display_login': 'PauPerL',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PauPerL',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101154968?'},
#   'repo': {'id': 360849564,
#    'name': 'JosephineBiedermann/ironhack-case-study-classification',
#    'url': 'https://api.github.com/repos/JosephineBiedermann/ironhack-case-study-classification'},
#   'payload': {'forkee': {'id': 491782406,
#     'node_id': 'R_kgDOHVABBg',
#     'name': 'ironhack-case-study-classification',
#     'full_name': 'PauPerL/ironhack-case-study-classification',
#     'private': False,
#     'owner': {'login': 'PauPerL',
#      'id': 101154968,
#      'node_id': 'U_kgDOBgeAmA',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/101154968?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/PauPerL',
#      'html_url': 'https://github.com/PauPerL',
#      'followers_url': 'https://api.github.com/users/PauPerL/followers',
#      'following_url': 'https://api.github.com/users/PauPerL/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/PauPerL/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/PauPerL/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/PauPerL/subscriptions',
#      'organizations_url': 'https://api.github.com/users/PauPerL/orgs',
#      'repos_url': 'https://api.github.com/users/PauPerL/repos',
#      'events_url': 'https://api.github.com/users/PauPerL/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/PauPerL/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/PauPerL/ironhack-case-study-classification',
#     'description': None,
#     'fork': True,
#     'url': 'https://api.github.com/repos/PauPerL/ironhack-case-study-classification',
#     'forks_url': 'https://api.github.com/repos/PauPerL/ironhack-case-study-classification/forks',
#     'keys_url': 'https://api.github.com/repos/PauPerL/ironhack-case-study-classification/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/PauPerL/ironhack-case-study-classification/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/PauPerL/ironhack-case-study-classification/teams',
#     'hooks_url': 'https://api.github.com/repos/PauPerL/ironhack-case-study-classification/hooks',
#     'issue_events_url': 'https://api.github.com/repos/PauPerL/ironhack-case-study-classification/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/PauPerL/ironhack-case-study-classification/events',
#     'assignees_url': 'https://api.github.com/repos/PauPerL/ironhack-case-study-classification/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/PauPerL/ironhack-case-study-classification/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/PauPerL/ironhack-case-study-classification/tags',
#     'blobs_url': 'https://api.github.com/repos/PauPerL/ironhack-case-study-classification/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/PauPerL/ironhack-case-study-classification/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/PauPerL/ironhack-case-study-classification/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/PauPerL/ironhack-case-study-classification/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/PauPerL/ironhack-case-study-classification/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/PauPerL/ironhack-case-study-classification/languages',
#     'stargazers_url': 'https://api.github.com/repos/PauPerL/ironhack-case-study-classification/stargazers',
#     'contributors_url': 'https://api.github.com/repos/PauPerL/ironhack-case-study-classification/contributors',
#     'subscribers_url': 'https://api.github.com/repos/PauPerL/ironhack-case-study-classification/subscribers',
#     'subscription_url': 'https://api.github.com/repos/PauPerL/ironhack-case-study-classification/subscription',
#     'commits_url': 'https://api.github.com/repos/PauPerL/ironhack-case-study-classification/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/PauPerL/ironhack-case-study-classification/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/PauPerL/ironhack-case-study-classification/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/PauPerL/ironhack-case-study-classification/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/PauPerL/ironhack-case-study-classification/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/PauPerL/ironhack-case-study-classification/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/PauPerL/ironhack-case-study-classification/merges',
#     'archive_url': 'https://api.github.com/repos/PauPerL/ironhack-case-study-classification/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/PauPerL/ironhack-case-study-classification/downloads',
#     'issues_url': 'https://api.github.com/repos/PauPerL/ironhack-case-study-classification/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/PauPerL/ironhack-case-study-classification/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/PauPerL/ironhack-case-study-classification/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/PauPerL/ironhack-case-study-classification/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/PauPerL/ironhack-case-study-classification/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/PauPerL/ironhack-case-study-classification/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/PauPerL/ironhack-case-study-classification/deployments',
#     'created_at': '2022-05-13T06:27:21Z',
#     'updated_at': '2021-11-10T17:27:54Z',
#     'pushed_at': '2021-04-23T09:00:27Z',
#     'git_url': 'git://github.com/PauPerL/ironhack-case-study-classification.git',
#     'ssh_url': 'git@github.com:PauPerL/ironhack-case-study-classification.git',
#     'clone_url': 'https://github.com/PauPerL/ironhack-case-study-classification.git',
#     'svn_url': 'https://github.com/PauPerL/ironhack-case-study-classification',
#     'homepage': None,
#     'size': 14689,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'allow_forking': True,
#     'is_template': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'main',
#     'public': True}},
#   'public': True,
#   'created_at': '2022-05-13T06:27:21Z'},
#  {'id': '21768348544',
#   'type': 'CreateEvent',
#   'actor': {'id': 101154968,
#    'login': 'PauPerL',
#    'display_login': 'PauPerL',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PauPerL',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101154968?'},
#   'repo': {'id': 491779671,
#    'name': 'PauPerL/Midcamp_project',
#    'url': 'https://api.github.com/repos/PauPerL/Midcamp_project'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': 'Ironhack micamp project, real state scenario.',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-05-13T06:16:53Z'},
#  {'id': '21768347731',
#   'type': 'CreateEvent',
#   'actor': {'id': 101154968,
#    'login': 'PauPerL',
#    'display_login': 'PauPerL',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PauPerL',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101154968?'},
#   'repo': {'id': 491779671,
#    'name': 'PauPerL/Midcamp_project',
#    'url': 'https://api.github.com/repos/PauPerL/Midcamp_project'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': 'Ironhack micamp project, real state scenario.',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-05-13T06:16:49Z'},
#  {'id': '21758366038',
#   'type': 'ForkEvent',
#   'actor': {'id': 101154968,
#    'login': 'PauPerL',
#    'display_login': 'PauPerL',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PauPerL',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101154968?'},
#   'repo': {'id': 491540057,
#    'name': 'andy1coupe/RealEstateProject',
#    'url': 'https://api.github.com/repos/andy1coupe/RealEstateProject'},
#   'payload': {'forkee': {'id': 491582502,
#     'node_id': 'R_kgDOHUz0Jg',
#     'name': 'RealEstateProject',
#     'full_name': 'PauPerL/RealEstateProject',
#     'private': False,
#     'owner': {'login': 'PauPerL',
#      'id': 101154968,
#      'node_id': 'U_kgDOBgeAmA',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/101154968?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/PauPerL',
#      'html_url': 'https://github.com/PauPerL',
#      'followers_url': 'https://api.github.com/users/PauPerL/followers',
#      'following_url': 'https://api.github.com/users/PauPerL/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/PauPerL/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/PauPerL/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/PauPerL/subscriptions',
#      'organizations_url': 'https://api.github.com/users/PauPerL/orgs',
#      'repos_url': 'https://api.github.com/users/PauPerL/repos',
#      'events_url': 'https://api.github.com/users/PauPerL/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/PauPerL/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/PauPerL/RealEstateProject',
#     'description': None,
#     'fork': True,
#     'url': 'https://api.github.com/repos/PauPerL/RealEstateProject',
#     'forks_url': 'https://api.github.com/repos/PauPerL/RealEstateProject/forks',
#     'keys_url': 'https://api.github.com/repos/PauPerL/RealEstateProject/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/PauPerL/RealEstateProject/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/PauPerL/RealEstateProject/teams',
#     'hooks_url': 'https://api.github.com/repos/PauPerL/RealEstateProject/hooks',
#     'issue_events_url': 'https://api.github.com/repos/PauPerL/RealEstateProject/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/PauPerL/RealEstateProject/events',
#     'assignees_url': 'https://api.github.com/repos/PauPerL/RealEstateProject/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/PauPerL/RealEstateProject/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/PauPerL/RealEstateProject/tags',
#     'blobs_url': 'https://api.github.com/repos/PauPerL/RealEstateProject/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/PauPerL/RealEstateProject/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/PauPerL/RealEstateProject/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/PauPerL/RealEstateProject/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/PauPerL/RealEstateProject/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/PauPerL/RealEstateProject/languages',
#     'stargazers_url': 'https://api.github.com/repos/PauPerL/RealEstateProject/stargazers',
#     'contributors_url': 'https://api.github.com/repos/PauPerL/RealEstateProject/contributors',
#     'subscribers_url': 'https://api.github.com/repos/PauPerL/RealEstateProject/subscribers',
#     'subscription_url': 'https://api.github.com/repos/PauPerL/RealEstateProject/subscription',
#     'commits_url': 'https://api.github.com/repos/PauPerL/RealEstateProject/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/PauPerL/RealEstateProject/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/PauPerL/RealEstateProject/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/PauPerL/RealEstateProject/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/PauPerL/RealEstateProject/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/PauPerL/RealEstateProject/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/PauPerL/RealEstateProject/merges',
#     'archive_url': 'https://api.github.com/repos/PauPerL/RealEstateProject/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/PauPerL/RealEstateProject/downloads',
#     'issues_url': 'https://api.github.com/repos/PauPerL/RealEstateProject/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/PauPerL/RealEstateProject/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/PauPerL/RealEstateProject/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/PauPerL/RealEstateProject/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/PauPerL/RealEstateProject/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/PauPerL/RealEstateProject/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/PauPerL/RealEstateProject/deployments',
#     'created_at': '2022-05-12T16:06:13Z',
#     'updated_at': '2022-05-12T14:24:20Z',
#     'pushed_at': '2022-05-12T15:57:35Z',
#     'git_url': 'git://github.com/PauPerL/RealEstateProject.git',
#     'ssh_url': 'git@github.com:PauPerL/RealEstateProject.git',
#     'clone_url': 'https://github.com/PauPerL/RealEstateProject.git',
#     'svn_url': 'https://github.com/PauPerL/RealEstateProject',
#     'homepage': None,
#     'size': 5885,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'allow_forking': True,
#     'is_template': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'main',
#     'public': True}},
#   'public': True,
#   'created_at': '2022-05-12T16:06:13Z'},
#  {'id': '21650770800',
#   'type': 'PushEvent',
#   'actor': {'id': 101154968,
#    'login': 'PauPerL',
#    'display_login': 'PauPerL',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PauPerL',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101154968?'},
#   'repo': {'id': 488233830,
#    'name': 'PauPerL/BCNDATA2022',
#    'url': 'https://api.github.com/repos/PauPerL/BCNDATA2022'},
#   'payload': {'push_id': 9811244437,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'c5e207df710d3b445b48df4757608fc6d04af00c',
#    'before': '063135cae9ee2b7a2e5ffa20ef43c71d4cef18dd',
#    'commits': [{'sha': 'c5e207df710d3b445b48df4757608fc6d04af00c',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'removed and re added wine notebook under new name',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/commits/c5e207df710d3b445b48df4757608fc6d04af00c'}]},
#   'public': True,
#   'created_at': '2022-05-06T09:07:11Z'},
#  {'id': '21636721277',
#   'type': 'PushEvent',
#   'actor': {'id': 101154968,
#    'login': 'PauPerL',
#    'display_login': 'PauPerL',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PauPerL',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101154968?'},
#   'repo': {'id': 488233830,
#    'name': 'PauPerL/BCNDATA2022',
#    'url': 'https://api.github.com/repos/PauPerL/BCNDATA2022'},
#   'payload': {'push_id': 9804071518,
#    'size': 5,
#    'distinct_size': 5,
#    'ref': 'refs/heads/main',
#    'head': '063135cae9ee2b7a2e5ffa20ef43c71d4cef18dd',
#    'before': 'e7b8df2678f96148708fefc47979b085cd227730',
#    'commits': [{'sha': 'f2999f00e47e5a2e6184430f017f5bbd75e2fac8',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'Create Imbalanced_data.ipynb',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/commits/f2999f00e47e5a2e6184430f017f5bbd75e2fac8'},
#     {'sha': '03c6c8c74750a1c23890730190a795612f11db07',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'Update Imbalanced_data.ipynb',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/commits/03c6c8c74750a1c23890730190a795612f11db07'},
#     {'sha': '5863921bce905c3f7c3384116c29c22c903c9a7e',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'Create EDA_lesson.ipynb',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/commits/5863921bce905c3f7c3384116c29c22c903c9a7e'},
#     {'sha': 'f776695ba6a3dee9795607ef64c8a74ef2245b75',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'update EDA notebook',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/commits/f776695ba6a3dee9795607ef64c8a74ef2245b75'},
#     {'sha': '063135cae9ee2b7a2e5ffa20ef43c71d4cef18dd',
#      'author': {'email': 'sian.davies@ironhack.com', 'name': 'siandav'},
#      'message': 'end of day 4 week 4',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/commits/063135cae9ee2b7a2e5ffa20ef43c71d4cef18dd'}]},
#   'public': True,
#   'created_at': '2022-05-05T14:49:29Z'},
#  {'id': '21613284985',
#   'type': 'PushEvent',
#   'actor': {'id': 101154968,
#    'login': 'PauPerL',
#    'display_login': 'PauPerL',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PauPerL',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101154968?'},
#   'repo': {'id': 480380078,
#    'name': 'PauPerL/IronPau',
#    'url': 'https://api.github.com/repos/PauPerL/IronPau'},
#   'payload': {'push_id': 9792577274,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'd10161a4ede9ec7050f04e83b061d0f09d36bd54',
#    'before': '9a4367c686e0290c00db1dd2a2ef91e4069e8df2',
#    'commits': [{'sha': 'd10161a4ede9ec7050f04e83b061d0f09d36bd54',
#      'author': {'email': '101154968+PauPerL@users.noreply.github.com',
#       'name': 'PauPerL'},
#      'message': 'Micro cambio toggle output jupnotbook\n\nHe cambiado el output a una celda del notebook de jupyter de lab logistic reg para que no muestre etc',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PauPerL/IronPau/commits/d10161a4ede9ec7050f04e83b061d0f09d36bd54'}]},
#   'public': True,
#   'created_at': '2022-05-04T12:26:59Z'},
#  {'id': '21612923353',
#   'type': 'PushEvent',
#   'actor': {'id': 101154968,
#    'login': 'PauPerL',
#    'display_login': 'PauPerL',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PauPerL',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101154968?'},
#   'repo': {'id': 480380078,
#    'name': 'PauPerL/IronPau',
#    'url': 'https://api.github.com/repos/PauPerL/IronPau'},
#   'payload': {'push_id': 9792398036,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '9a4367c686e0290c00db1dd2a2ef91e4069e8df2',
#    'before': 'bfdbf069e9970374377e3daa41923cabd1d20270',
#    'commits': [{'sha': '9a4367c686e0290c00db1dd2a2ef91e4069e8df2',
#      'author': {'email': '101154968+PauPerL@users.noreply.github.com',
#       'name': 'PauPerL'},
#      'message': 'Lab Imbalanced data + pickle things?\n\nLab de Imbalanced data mas cositas y pequeños cambios de pickle y cosas asi',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PauPerL/IronPau/commits/9a4367c686e0290c00db1dd2a2ef91e4069e8df2'}]},
#   'public': True,
#   'created_at': '2022-05-04T12:06:29Z'},
#  {'id': '21608164900',
#   'type': 'WatchEvent',
#   'actor': {'id': 101154968,
#    'login': 'PauPerL',
#    'display_login': 'PauPerL',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PauPerL',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101154968?'},
#   'repo': {'id': 480380078,
#    'name': 'PauPerL/IronPau',
#    'url': 'https://api.github.com/repos/PauPerL/IronPau'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2022-05-04T07:11:03Z'},
#  {'id': '21595145663',
#   'type': 'ForkEvent',
#   'actor': {'id': 101154968,
#    'login': 'PauPerL',
#    'display_login': 'PauPerL',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PauPerL',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101154968?'},
#   'repo': {'id': 446439899,
#    'name': 'student-IH-labs-and-stuff/BCNDATA2022',
#    'url': 'https://api.github.com/repos/student-IH-labs-and-stuff/BCNDATA2022'},
#   'payload': {'forkee': {'id': 488233830,
#     'node_id': 'R_kgDOHRnbZg',
#     'name': 'BCNDATA2022',
#     'full_name': 'PauPerL/BCNDATA2022',
#     'private': False,
#     'owner': {'login': 'PauPerL',
#      'id': 101154968,
#      'node_id': 'U_kgDOBgeAmA',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/101154968?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/PauPerL',
#      'html_url': 'https://github.com/PauPerL',
#      'followers_url': 'https://api.github.com/users/PauPerL/followers',
#      'following_url': 'https://api.github.com/users/PauPerL/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/PauPerL/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/PauPerL/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/PauPerL/subscriptions',
#      'organizations_url': 'https://api.github.com/users/PauPerL/orgs',
#      'repos_url': 'https://api.github.com/users/PauPerL/repos',
#      'events_url': 'https://api.github.com/users/PauPerL/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/PauPerL/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/PauPerL/BCNDATA2022',
#     'description': 'class repo for barcelona data 2022 classes with sian',
#     'fork': True,
#     'url': 'https://api.github.com/repos/PauPerL/BCNDATA2022',
#     'forks_url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/forks',
#     'keys_url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/teams',
#     'hooks_url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/hooks',
#     'issue_events_url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/events',
#     'assignees_url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/tags',
#     'blobs_url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/languages',
#     'stargazers_url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/stargazers',
#     'contributors_url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/contributors',
#     'subscribers_url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/subscribers',
#     'subscription_url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/subscription',
#     'commits_url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/merges',
#     'archive_url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/downloads',
#     'issues_url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/PauPerL/BCNDATA2022/deployments',
#     'created_at': '2022-05-03T14:04:07Z',
#     'updated_at': '2022-04-14T13:45:18Z',
#     'pushed_at': '2022-05-03T13:48:55Z',
#     'git_url': 'git://github.com/PauPerL/BCNDATA2022.git',
#     'ssh_url': 'git@github.com:PauPerL/BCNDATA2022.git',
#     'clone_url': 'https://github.com/PauPerL/BCNDATA2022.git',
#     'svn_url': 'https://github.com/PauPerL/BCNDATA2022',
#     'homepage': '',
#     'size': 315825,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'allow_forking': True,
#     'is_template': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'main',
#     'public': True}},
#   'public': True,
#   'created_at': '2022-05-03T14:04:07Z',
#   'org': {'id': 72746426,
#    'login': 'student-IH-labs-and-stuff',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/student-IH-labs-and-stuff',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/72746426?'}},
#  {'id': '21594609952',
#   'type': 'PushEvent',
#   'actor': {'id': 101154968,
#    'login': 'PauPerL',
#    'display_login': 'PauPerL',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PauPerL',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101154968?'},
#   'repo': {'id': 480380078,
#    'name': 'PauPerL/IronPau',
#    'url': 'https://api.github.com/repos/PauPerL/IronPau'},
#   'payload': {'push_id': 9783362817,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'bfdbf069e9970374377e3daa41923cabd1d20270',
#    'before': 'd8daa9f72d11d30c01b623371c60bd1a66461fe7',
#    'commits': [{'sha': 'bfdbf069e9970374377e3daa41923cabd1d20270',
#      'author': {'email': '101154968+PauPerL@users.noreply.github.com',
#       'name': 'PauPerL'},
#      'message': 'Pequeña actualizacion de lab_logistic_reg\n\nsimple actualizacion con el ultimo punto de crear carpetas y el uso de pickles en el lab lab_logistic_reg del dia w4d2',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PauPerL/IronPau/commits/bfdbf069e9970374377e3daa41923cabd1d20270'}]},
#   'public': True,
#   'created_at': '2022-05-03T13:37:38Z'},
#  {'id': '21592097194',
#   'type': 'PushEvent',
#   'actor': {'id': 101154968,
#    'login': 'PauPerL',
#    'display_login': 'PauPerL',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PauPerL',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101154968?'},
#   'repo': {'id': 480380078,
#    'name': 'PauPerL/IronPau',
#    'url': 'https://api.github.com/repos/PauPerL/IronPau'},
#   'payload': {'push_id': 9782103413,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'd8daa9f72d11d30c01b623371c60bd1a66461fe7',
#    'before': 'b845e701f3806a1f043d27b82a89ea575669f950',
#    'commits': [{'sha': 'd8daa9f72d11d30c01b623371c60bd1a66461fe7',
#      'author': {'email': '101154968+PauPerL@users.noreply.github.com',
#       'name': 'PauPerL'},
#      'message': 'Lab logistic reg + cosas dia anterior\n\nUn monton de cosas del dia anterior, clases y mierdas y lab de regresion logistica (con sklearning etc) machine leraning hecho el dia w4d2',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PauPerL/IronPau/commits/d8daa9f72d11d30c01b623371c60bd1a66461fe7'}]},
#   'public': True,
#   'created_at': '2022-05-03T11:04:19Z'},
#  {'id': '21574727833',
#   'type': 'PushEvent',
#   'actor': {'id': 101154968,
#    'login': 'PauPerL',
#    'display_login': 'PauPerL',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PauPerL',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101154968?'},
#   'repo': {'id': 480380078,
#    'name': 'PauPerL/IronPau',
#    'url': 'https://api.github.com/repos/PauPerL/IronPau'},
#   'payload': {'push_id': 9773569447,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'b845e701f3806a1f043d27b82a89ea575669f950',
#    'before': '161fc90d462101d82316a7f72e8142c94c365574',
#    'commits': [{'sha': 'b845e701f3806a1f043d27b82a89ea575669f950',
#      'author': {'email': '101154968+PauPerL@users.noreply.github.com',
#       'name': 'PauPerL'},
#      'message': 'A bit update to the first lab\n\nw4d1 pequeños retoques para el lab segun las correciciones de la profe',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PauPerL/IronPau/commits/b845e701f3806a1f043d27b82a89ea575669f950'}]},
#   'public': True,
#   'created_at': '2022-05-02T12:36:06Z'},
#  {'id': '21572898709',
#   'type': 'PushEvent',
#   'actor': {'id': 101154968,
#    'login': 'PauPerL',
#    'display_login': 'PauPerL',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PauPerL',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101154968?'},
#   'repo': {'id': 480380078,
#    'name': 'PauPerL/IronPau',
#    'url': 'https://api.github.com/repos/PauPerL/IronPau'},
#   'payload': {'push_id': 9772640000,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '161fc90d462101d82316a7f72e8142c94c365574',
#    'before': '40f91adc09ce0d5f4148237967ae5697be7186f1',
#    'commits': [{'sha': '161fc90d462101d82316a7f72e8142c94c365574',
#      'author': {'email': '101154968+PauPerL@users.noreply.github.com',
#       'name': 'PauPerL'},
#      'message': 'lab sql with python\n\nlab hecho por la mañana del w4d1 de sql en python y pandas',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PauPerL/IronPau/commits/161fc90d462101d82316a7f72e8142c94c365574'}]},
#   'public': True,
#   'created_at': '2022-05-02T10:25:00Z'},
#  {'id': '21546170967',
#   'type': 'PushEvent',
#   'actor': {'id': 101154968,
#    'login': 'PauPerL',
#    'display_login': 'PauPerL',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PauPerL',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101154968?'},
#   'repo': {'id': 480380078,
#    'name': 'PauPerL/IronPau',
#    'url': 'https://api.github.com/repos/PauPerL/IronPau'},
#   'payload': {'push_id': 9757424507,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '40f91adc09ce0d5f4148237967ae5697be7186f1',
#    'before': '2619e456960cedc2e8d5a5ca42293c489fa833ef',
#    'commits': [{'sha': '40f91adc09ce0d5f4148237967ae5697be7186f1',
#      'author': {'email': '101154968+PauPerL@users.noreply.github.com',
#       'name': 'PauPerL'},
#      'message': 'Conexion python mysql\n\nUltima clase del dia w3d5 conexion entre  python y mysql',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PauPerL/IronPau/commits/40f91adc09ce0d5f4148237967ae5697be7186f1'}]},
#   'public': True,
#   'created_at': '2022-04-29T15:57:27Z'},
#  {'id': '21543461369',
#   'type': 'PushEvent',
#   'actor': {'id': 101154968,
#    'login': 'PauPerL',
#    'display_login': 'PauPerL',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PauPerL',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101154968?'},
#   'repo': {'id': 480380078,
#    'name': 'PauPerL/IronPau',
#    'url': 'https://api.github.com/repos/PauPerL/IronPau'},
#   'payload': {'push_id': 9756187922,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '2619e456960cedc2e8d5a5ca42293c489fa833ef',
#    'before': '0f736ad18524e29fb873def1e5e66d9d6295f742',
#    'commits': [{'sha': '2619e456960cedc2e8d5a5ca42293c489fa833ef',
#      'author': {'email': '101154968+PauPerL@users.noreply.github.com',
#       'name': 'PauPerL'},
#      'message': 'Labs sql joins y subquerys\n\nLab durante la mañana w3d5 sql probando joins subquerys etc.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PauPerL/IronPau/commits/2619e456960cedc2e8d5a5ca42293c489fa833ef'}]},
#   'public': True,
#   'created_at': '2022-04-29T13:54:00Z'},
#  {'id': '21517174773',
#   'type': 'PushEvent',
#   'actor': {'id': 101154968,
#    'login': 'PauPerL',
#    'display_login': 'PauPerL',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PauPerL',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101154968?'},
#   'repo': {'id': 480380078,
#    'name': 'PauPerL/IronPau',
#    'url': 'https://api.github.com/repos/PauPerL/IronPau'},
#   'payload': {'push_id': 9743608225,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '0f736ad18524e29fb873def1e5e66d9d6295f742',
#    'before': '237e7fae958caa9d64cb61d4ae2b274fc9e473b6',
#    'commits': [{'sha': '0f736ad18524e29fb873def1e5e66d9d6295f742',
#      'author': {'email': '101154968+PauPerL@users.noreply.github.com',
#       'name': 'PauPerL'},
#      'message': 'clases sql joins etc\n\nClases por la mañana de sql w3d4 hacemos joins y ejercicios de joins etc',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PauPerL/IronPau/commits/0f736ad18524e29fb873def1e5e66d9d6295f742'}]},
#   'public': True,
#   'created_at': '2022-04-28T11:00:43Z'},
#  {'id': '21514200133',
#   'type': 'PushEvent',
#   'actor': {'id': 101154968,
#    'login': 'PauPerL',
#    'display_login': 'PauPerL',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PauPerL',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101154968?'},
#   'repo': {'id': 480380078,
#    'name': 'PauPerL/IronPau',
#    'url': 'https://api.github.com/repos/PauPerL/IronPau'},
#   'payload': {'push_id': 9742166100,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '237e7fae958caa9d64cb61d4ae2b274fc9e473b6',
#    'before': '957100d27956b72b740a7a738a272a11ded40548',
#    'commits': [{'sha': '237e7fae958caa9d64cb61d4ae2b274fc9e473b6',
#      'author': {'email': '101154968+PauPerL@users.noreply.github.com',
#       'name': 'PauPerL'},
#      'message': 'Lab SQL Queries y reordenamiento\n\nLab SQL Queries por la mañana del w3d4 y reordenamiento de las  carpetas clase y labs',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PauPerL/IronPau/commits/237e7fae958caa9d64cb61d4ae2b274fc9e473b6'}]},
#   'public': True,
#   'created_at': '2022-04-28T08:23:33Z'},
#  {'id': '21495398647',
#   'type': 'PushEvent',
#   'actor': {'id': 101154968,
#    'login': 'PauPerL',
#    'display_login': 'PauPerL',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PauPerL',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101154968?'},
#   'repo': {'id': 480380078,
#    'name': 'PauPerL/IronPau',
#    'url': 'https://api.github.com/repos/PauPerL/IronPau'},
#   'payload': {'push_id': 9732937269,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '957100d27956b72b740a7a738a272a11ded40548',
#    'before': 'f63a4061e4f9392241a65501955b80fc614085ef',
#    'commits': [{'sha': '957100d27956b72b740a7a738a272a11ded40548',
#      'author': {'email': '101154968+PauPerL@users.noreply.github.com',
#       'name': 'PauPerL'},
#      'message': 'Correcciones lab sql preprocessing\n\nmas correccriones al lab sql preprocessing y el primer ejemplo de subquery hecho.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PauPerL/IronPau/commits/957100d27956b72b740a7a738a272a11ded40548'}]},
#   'public': True,
#   'created_at': '2022-04-27T11:08:42Z'},
#  {'id': '21494274114',
#   'type': 'PushEvent',
#   'actor': {'id': 101154968,
#    'login': 'PauPerL',
#    'display_login': 'PauPerL',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PauPerL',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101154968?'},
#   'repo': {'id': 480380078,
#    'name': 'PauPerL/IronPau',
#    'url': 'https://api.github.com/repos/PauPerL/IronPau'},
#   'payload': {'push_id': 9732391775,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'f63a4061e4f9392241a65501955b80fc614085ef',
#    'before': 'f69fa4e35c4822371bc69d489d21ac1f68984868',
#    'commits': [{'sha': 'f63a4061e4f9392241a65501955b80fc614085ef',
#      'author': {'email': '101154968+PauPerL@users.noreply.github.com',
#       'name': 'PauPerL'},
#      'message': 'Pequeño cambio al lab sql preprocessing',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PauPerL/IronPau/commits/f63a4061e4f9392241a65501955b80fc614085ef'}]},
#   'public': True,
#   'created_at': '2022-04-27T10:06:39Z'},
#  {'id': '21493765816',
#   'type': 'PushEvent',
#   'actor': {'id': 101154968,
#    'login': 'PauPerL',
#    'display_login': 'PauPerL',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PauPerL',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101154968?'},
#   'repo': {'id': 480380078,
#    'name': 'PauPerL/IronPau',
#    'url': 'https://api.github.com/repos/PauPerL/IronPau'},
#   'payload': {'push_id': 9732146098,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'f69fa4e35c4822371bc69d489d21ac1f68984868',
#    'before': 'ccb27074f7522575b3434b9080c6bd08ff0cd87f',
#    'commits': [{'sha': 'f69fa4e35c4822371bc69d489d21ac1f68984868',
#      'author': {'email': '101154968+PauPerL@users.noreply.github.com',
#       'name': 'PauPerL'},
#      'message': 'Lab sql preprocessing\n\nlab sql preprocessing dia w3d3',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PauPerL/IronPau/commits/f69fa4e35c4822371bc69d489d21ac1f68984868'}]},
#   'public': True,
#   'created_at': '2022-04-27T09:40:29Z'},
#  {'id': '21479099887',
#   'type': 'PushEvent',
#   'actor': {'id': 101154968,
#    'login': 'PauPerL',
#    'display_login': 'PauPerL',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PauPerL',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101154968?'},
#   'repo': {'id': 480380078,
#    'name': 'PauPerL/IronPau',
#    'url': 'https://api.github.com/repos/PauPerL/IronPau'},
#   'payload': {'push_id': 9724913965,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'ccb27074f7522575b3434b9080c6bd08ff0cd87f',
#    'before': '429e6a4af09e759d74cfe5180af22a8308352b29',
#    'commits': [{'sha': 'ccb27074f7522575b3434b9080c6bd08ff0cd87f',
#      'author': {'email': '101154968+PauPerL@users.noreply.github.com',
#       'name': 'PauPerL'},
#      'message': 'Inicio de mySQL w3d2\n\nEmpezamos a tocar mysql y hacemos nuestro primer lab.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PauPerL/IronPau/commits/ccb27074f7522575b3434b9080c6bd08ff0cd87f'}]},
#   'public': True,
#   'created_at': '2022-04-26T15:59:25Z'},
#  {'id': '21468495837',
#   'type': 'PushEvent',
#   'actor': {'id': 101154968,
#    'login': 'PauPerL',
#    'display_login': 'PauPerL',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PauPerL',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/101154968?'},
#   'repo': {'id': 483194390,
#    'name': 'PauPerL/Messy_Data',
#    'url': 'https://api.github.com/repos/PauPerL/Messy_Data'},
#   'payload': {'push_id': 9719816904,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'efba31b1c14623eefd785cbcb8145d3fefb3729a',
#    'before': 'c3908eef553c195a157697e38ea63859dff97b69',
#    'commits': [{'sha': 'efba31b1c14623eefd785cbcb8145d3fefb3729a',
#      'author': {'email': '101154968+PauPerL@users.noreply.github.com',
#       'name': 'PauPerL'},
#      'message': 'Final push everything done\n\nWe alredy have done everything on the project and its closed. No changes since friday today im at w3d2',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PauPerL/Messy_Data/commits/efba31b1c14623eefd785cbcb8145d3fefb3729a'}]},
#   'public': True,
#   'created_at': '2022-04-26T07:20:09Z'}]

# %%
import pandas as pd

# %%
pd.DataFrame(github_response.json())
# Out:
#              id         type  \
# 0   21951900136    PushEvent
# 1   21951857184    PushEvent
# 2   21900153692    PushEvent
# 3   21807893820    PushEvent
# 4   21770086046    PushEvent
# 5   21769709223    PushEvent
# 6   21768975038    PushEvent
# 7   21768478912    ForkEvent
# 8   21768348544  CreateEvent
# 9   21768347731  CreateEvent
# 10  21758366038    ForkEvent
# 11  21650770800    PushEvent
# 12  21636721277    PushEvent
# 13  21613284985    PushEvent
# 14  21612923353    PushEvent
# 15  21608164900   WatchEvent
# 16  21595145663    ForkEvent
# 17  21594609952    PushEvent
# 18  21592097194    PushEvent
# 19  21574727833    PushEvent
# 20  21572898709    PushEvent
# 21  21546170967    PushEvent
# 22  21543461369    PushEvent
# 23  21517174773    PushEvent
# 24  21514200133    PushEvent
# 25  21495398647    PushEvent
# 26  21494274114    PushEvent
# 27  21493765816    PushEvent
# 28  21479099887    PushEvent
# 29  21468495837    PushEvent
#
#                                                 actor  \
# 0   {'id': 101154968, 'login': 'PauPerL', 'display...
# 1   {'id': 101154968, 'login': 'PauPerL', 'display...
# 2   {'id': 101154968, 'login': 'PauPerL', 'display...
# 3   {'id': 101154968, 'login': 'PauPerL', 'display...
# 4   {'id': 101154968, 'login': 'PauPerL', 'display...
# 5   {'id': 101154968, 'login': 'PauPerL', 'display...
# 6   {'id': 101154968, 'login': 'PauPerL', 'display...
# 7   {'id': 101154968, 'login': 'PauPerL', 'display...
# 8   {'id': 101154968, 'login': 'PauPerL', 'display...
# 9   {'id': 101154968, 'login': 'PauPerL', 'display...
# 10  {'id': 101154968, 'login': 'PauPerL', 'display...
# 11  {'id': 101154968, 'login': 'PauPerL', 'display...
# 12  {'id': 101154968, 'login': 'PauPerL', 'display...
# 13  {'id': 101154968, 'login': 'PauPerL', 'display...
# 14  {'id': 101154968, 'login': 'PauPerL', 'display...
# 15  {'id': 101154968, 'login': 'PauPerL', 'display...
# 16  {'id': 101154968, 'login': 'PauPerL', 'display...
# 17  {'id': 101154968, 'login': 'PauPerL', 'display...
# 18  {'id': 101154968, 'login': 'PauPerL', 'display...
# 19  {'id': 101154968, 'login': 'PauPerL', 'display...
# 20  {'id': 101154968, 'login': 'PauPerL', 'display...
# 21  {'id': 101154968, 'login': 'PauPerL', 'display...
# 22  {'id': 101154968, 'login': 'PauPerL', 'display...
# 23  {'id': 101154968, 'login': 'PauPerL', 'display...
# 24  {'id': 101154968, 'login': 'PauPerL', 'display...
# 25  {'id': 101154968, 'login': 'PauPerL', 'display...
# 26  {'id': 101154968, 'login': 'PauPerL', 'display...
# 27  {'id': 101154968, 'login': 'PauPerL', 'display...
# 28  {'id': 101154968, 'login': 'PauPerL', 'display...
# 29  {'id': 101154968, 'login': 'PauPerL', 'display...
#
#                                                  repo  \
# 0   {'id': 480380078, 'name': 'PauPerL/IronPau', '...
# 1   {'id': 480380078, 'name': 'PauPerL/IronPau', '...
# 2   {'id': 480380078, 'name': 'PauPerL/IronPau', '...
# 3   {'id': 488233830, 'name': 'PauPerL/BCNDATA2022...
# 4   {'id': 491779671, 'name': 'PauPerL/Midcamp_pro...
# 5   {'id': 491779671, 'name': 'PauPerL/Midcamp_pro...
# 6   {'id': 491779671, 'name': 'PauPerL/Midcamp_pro...
# 7   {'id': 360849564, 'name': 'JosephineBiedermann...
# 8   {'id': 491779671, 'name': 'PauPerL/Midcamp_pro...
# 9   {'id': 491779671, 'name': 'PauPerL/Midcamp_pro...
# 10  {'id': 491540057, 'name': 'andy1coupe/RealEsta...
# 11  {'id': 488233830, 'name': 'PauPerL/BCNDATA2022...
# 12  {'id': 488233830, 'name': 'PauPerL/BCNDATA2022...
# 13  {'id': 480380078, 'name': 'PauPerL/IronPau', '...
# 14  {'id': 480380078, 'name': 'PauPerL/IronPau', '...
# 15  {'id': 480380078, 'name': 'PauPerL/IronPau', '...
# 16  {'id': 446439899, 'name': 'student-IH-labs-and...
# 17  {'id': 480380078, 'name': 'PauPerL/IronPau', '...
# 18  {'id': 480380078, 'name': 'PauPerL/IronPau', '...
# 19  {'id': 480380078, 'name': 'PauPerL/IronPau', '...
# 20  {'id': 480380078, 'name': 'PauPerL/IronPau', '...
# 21  {'id': 480380078, 'name': 'PauPerL/IronPau', '...
# 22  {'id': 480380078, 'name': 'PauPerL/IronPau', '...
# 23  {'id': 480380078, 'name': 'PauPerL/IronPau', '...
# 24  {'id': 480380078, 'name': 'PauPerL/IronPau', '...
# 25  {'id': 480380078, 'name': 'PauPerL/IronPau', '...
# 26  {'id': 480380078, 'name': 'PauPerL/IronPau', '...
# 27  {'id': 480380078, 'name': 'PauPerL/IronPau', '...
# 28  {'id': 480380078, 'name': 'PauPerL/IronPau', '...
# 29  {'id': 483194390, 'name': 'PauPerL/Messy_Data'...
#
#                                               payload  public  \
# 0   {'push_id': 9966412882, 'size': 1, 'distinct_s...    True
# 1   {'push_id': 9966392718, 'size': 1, 'distinct_s...    True
# 2   {'push_id': 9938448242, 'size': 1, 'distinct_s...    True
# 3   {'push_id': 9893476400, 'size': 8, 'distinct_s...    True
# 4   {'push_id': 9872551334, 'size': 1, 'distinct_s...    True
# 5   {'push_id': 9872364775, 'size': 1, 'distinct_s...    True
# 6   {'push_id': 9871999126, 'size': 1, 'distinct_s...    True
# 7   {'forkee': {'id': 491782406, 'node_id': 'R_kgD...    True
# 8   {'ref': 'main', 'ref_type': 'branch', 'master_...    True
# 9   {'ref': None, 'ref_type': 'repository', 'maste...    True
# 10  {'forkee': {'id': 491582502, 'node_id': 'R_kgD...    True
# 11  {'push_id': 9811244437, 'size': 1, 'distinct_s...    True
# 12  {'push_id': 9804071518, 'size': 5, 'distinct_s...    True
# 13  {'push_id': 9792577274, 'size': 1, 'distinct_s...    True
# 14  {'push_id': 9792398036, 'size': 1, 'distinct_s...    True
# 15                              {'action': 'started'}    True
# 16  {'forkee': {'id': 488233830, 'node_id': 'R_kgD...    True
# 17  {'push_id': 9783362817, 'size': 1, 'distinct_s...    True
# 18  {'push_id': 9782103413, 'size': 1, 'distinct_s...    True
# 19  {'push_id': 9773569447, 'size': 1, 'distinct_s...    True
# 20  {'push_id': 9772640000, 'size': 1, 'distinct_s...    True
# 21  {'push_id': 9757424507, 'size': 1, 'distinct_s...    True
# 22  {'push_id': 9756187922, 'size': 1, 'distinct_s...    True
# 23  {'push_id': 9743608225, 'size': 1, 'distinct_s...    True
# 24  {'push_id': 9742166100, 'size': 1, 'distinct_s...    True
# 25  {'push_id': 9732937269, 'size': 1, 'distinct_s...    True
# 26  {'push_id': 9732391775, 'size': 1, 'distinct_s...    True
# 27  {'push_id': 9732146098, 'size': 1, 'distinct_s...    True
# 28  {'push_id': 9724913965, 'size': 1, 'distinct_s...    True
# 29  {'push_id': 9719816904, 'size': 1, 'distinct_s...    True
#
#               created_at                                                org
# 0   2022-05-24T08:40:17Z                                                NaN
# 1   2022-05-24T08:38:13Z                                                NaN
# 2   2022-05-20T12:40:42Z                                                NaN
# 3   2022-05-16T12:07:19Z                                                NaN
# 4   2022-05-13T08:12:54Z                                                NaN
# 5   2022-05-13T07:50:37Z                                                NaN
# 6   2022-05-13T07:03:37Z                                                NaN
# 7   2022-05-13T06:27:21Z                                                NaN
# 8   2022-05-13T06:16:53Z                                                NaN
# 9   2022-05-13T06:16:49Z                                                NaN
# 10  2022-05-12T16:06:13Z                                                NaN
# 11  2022-05-06T09:07:11Z                                                NaN
# 12  2022-05-05T14:49:29Z                                                NaN
# 13  2022-05-04T12:26:59Z                                                NaN
# 14  2022-05-04T12:06:29Z                                                NaN
# 15  2022-05-04T07:11:03Z                                                NaN
# 16  2022-05-03T14:04:07Z  {'id': 72746426, 'login': 'student-IH-labs-and...
# 17  2022-05-03T13:37:38Z                                                NaN
# 18  2022-05-03T11:04:19Z                                                NaN
# 19  2022-05-02T12:36:06Z                                                NaN
# 20  2022-05-02T10:25:00Z                                                NaN
# 21  2022-04-29T15:57:27Z                                                NaN
# 22  2022-04-29T13:54:00Z                                                NaN
# 23  2022-04-28T11:00:43Z                                                NaN
# 24  2022-04-28T08:23:33Z                                                NaN
# 25  2022-04-27T11:08:42Z                                                NaN
# 26  2022-04-27T10:06:39Z                                                NaN
# 27  2022-04-27T09:40:29Z                                                NaN
# 28  2022-04-26T15:59:25Z                                                NaN
# 29  2022-04-26T07:20:09Z                                                NaN

# %%
github_df=pd.json_normalize(github_response.json())

# %%
github_df
# Out:
#              id         type  public            created_at   actor.id  \
# 0   21951900136    PushEvent    True  2022-05-24T08:40:17Z  101154968
# 1   21951857184    PushEvent    True  2022-05-24T08:38:13Z  101154968
# 2   21900153692    PushEvent    True  2022-05-20T12:40:42Z  101154968
# 3   21807893820    PushEvent    True  2022-05-16T12:07:19Z  101154968
# 4   21770086046    PushEvent    True  2022-05-13T08:12:54Z  101154968
# 5   21769709223    PushEvent    True  2022-05-13T07:50:37Z  101154968
# 6   21768975038    PushEvent    True  2022-05-13T07:03:37Z  101154968
# 7   21768478912    ForkEvent    True  2022-05-13T06:27:21Z  101154968
# 8   21768348544  CreateEvent    True  2022-05-13T06:16:53Z  101154968
# 9   21768347731  CreateEvent    True  2022-05-13T06:16:49Z  101154968
# 10  21758366038    ForkEvent    True  2022-05-12T16:06:13Z  101154968
# 11  21650770800    PushEvent    True  2022-05-06T09:07:11Z  101154968
# 12  21636721277    PushEvent    True  2022-05-05T14:49:29Z  101154968
# 13  21613284985    PushEvent    True  2022-05-04T12:26:59Z  101154968
# 14  21612923353    PushEvent    True  2022-05-04T12:06:29Z  101154968
# 15  21608164900   WatchEvent    True  2022-05-04T07:11:03Z  101154968
# 16  21595145663    ForkEvent    True  2022-05-03T14:04:07Z  101154968
# 17  21594609952    PushEvent    True  2022-05-03T13:37:38Z  101154968
# 18  21592097194    PushEvent    True  2022-05-03T11:04:19Z  101154968
# 19  21574727833    PushEvent    True  2022-05-02T12:36:06Z  101154968
# 20  21572898709    PushEvent    True  2022-05-02T10:25:00Z  101154968
# 21  21546170967    PushEvent    True  2022-04-29T15:57:27Z  101154968
# 22  21543461369    PushEvent    True  2022-04-29T13:54:00Z  101154968
# 23  21517174773    PushEvent    True  2022-04-28T11:00:43Z  101154968
# 24  21514200133    PushEvent    True  2022-04-28T08:23:33Z  101154968
# 25  21495398647    PushEvent    True  2022-04-27T11:08:42Z  101154968
# 26  21494274114    PushEvent    True  2022-04-27T10:06:39Z  101154968
# 27  21493765816    PushEvent    True  2022-04-27T09:40:29Z  101154968
# 28  21479099887    PushEvent    True  2022-04-26T15:59:25Z  101154968
# 29  21468495837    PushEvent    True  2022-04-26T07:20:09Z  101154968
#
#    actor.login actor.display_login actor.gravatar_id  \
# 0      PauPerL             PauPerL
# 1      PauPerL             PauPerL
# 2      PauPerL             PauPerL
# 3      PauPerL             PauPerL
# 4      PauPerL             PauPerL
# 5      PauPerL             PauPerL
# 6      PauPerL             PauPerL
# 7      PauPerL             PauPerL
# 8      PauPerL             PauPerL
# 9      PauPerL             PauPerL
# 10     PauPerL             PauPerL
# 11     PauPerL             PauPerL
# 12     PauPerL             PauPerL
# 13     PauPerL             PauPerL
# 14     PauPerL             PauPerL
# 15     PauPerL             PauPerL
# 16     PauPerL             PauPerL
# 17     PauPerL             PauPerL
# 18     PauPerL             PauPerL
# 19     PauPerL             PauPerL
# 20     PauPerL             PauPerL
# 21     PauPerL             PauPerL
# 22     PauPerL             PauPerL
# 23     PauPerL             PauPerL
# 24     PauPerL             PauPerL
# 25     PauPerL             PauPerL
# 26     PauPerL             PauPerL
# 27     PauPerL             PauPerL
# 28     PauPerL             PauPerL
# 29     PauPerL             PauPerL
#
#                                actor.url  \
# 0   https://api.github.com/users/PauPerL
# 1   https://api.github.com/users/PauPerL
# 2   https://api.github.com/users/PauPerL
# 3   https://api.github.com/users/PauPerL
# 4   https://api.github.com/users/PauPerL
# 5   https://api.github.com/users/PauPerL
# 6   https://api.github.com/users/PauPerL
# 7   https://api.github.com/users/PauPerL
# 8   https://api.github.com/users/PauPerL
# 9   https://api.github.com/users/PauPerL
# 10  https://api.github.com/users/PauPerL
# 11  https://api.github.com/users/PauPerL
# 12  https://api.github.com/users/PauPerL
# 13  https://api.github.com/users/PauPerL
# 14  https://api.github.com/users/PauPerL
# 15  https://api.github.com/users/PauPerL
# 16  https://api.github.com/users/PauPerL
# 17  https://api.github.com/users/PauPerL
# 18  https://api.github.com/users/PauPerL
# 19  https://api.github.com/users/PauPerL
# 20  https://api.github.com/users/PauPerL
# 21  https://api.github.com/users/PauPerL
# 22  https://api.github.com/users/PauPerL
# 23  https://api.github.com/users/PauPerL
# 24  https://api.github.com/users/PauPerL
# 25  https://api.github.com/users/PauPerL
# 26  https://api.github.com/users/PauPerL
# 27  https://api.github.com/users/PauPerL
# 28  https://api.github.com/users/PauPerL
# 29  https://api.github.com/users/PauPerL
#
#                                      actor.avatar_url  ...  payload.ref_type  \
# 0   https://avatars.githubusercontent.com/u/101154...  ...               NaN
# 1   https://avatars.githubusercontent.com/u/101154...  ...               NaN
# 2   https://avatars.githubusercontent.com/u/101154...  ...               NaN
# 3   https://avatars.githubusercontent.com/u/101154...  ...               NaN
# 4   https://avatars.githubusercontent.com/u/101154...  ...               NaN
# 5   https://avatars.githubusercontent.com/u/101154...  ...               NaN
# 6   https://avatars.githubusercontent.com/u/101154...  ...               NaN
# 7   https://avatars.githubusercontent.com/u/101154...  ...               NaN
# 8   https://avatars.githubusercontent.com/u/101154...  ...            branch
# 9   https://avatars.githubusercontent.com/u/101154...  ...        repository
# 10  https://avatars.githubusercontent.com/u/101154...  ...               NaN
# 11  https://avatars.githubusercontent.com/u/101154...  ...               NaN
# 12  https://avatars.githubusercontent.com/u/101154...  ...               NaN
# 13  https://avatars.githubusercontent.com/u/101154...  ...               NaN
# 14  https://avatars.githubusercontent.com/u/101154...  ...               NaN
# 15  https://avatars.githubusercontent.com/u/101154...  ...               NaN
# 16  https://avatars.githubusercontent.com/u/101154...  ...               NaN
# 17  https://avatars.githubusercontent.com/u/101154...  ...               NaN
# 18  https://avatars.githubusercontent.com/u/101154...  ...               NaN
# 19  https://avatars.githubusercontent.com/u/101154...  ...               NaN
# 20  https://avatars.githubusercontent.com/u/101154...  ...               NaN
# 21  https://avatars.githubusercontent.com/u/101154...  ...               NaN
# 22  https://avatars.githubusercontent.com/u/101154...  ...               NaN
# 23  https://avatars.githubusercontent.com/u/101154...  ...               NaN
# 24  https://avatars.githubusercontent.com/u/101154...  ...               NaN
# 25  https://avatars.githubusercontent.com/u/101154...  ...               NaN
# 26  https://avatars.githubusercontent.com/u/101154...  ...               NaN
# 27  https://avatars.githubusercontent.com/u/101154...  ...               NaN
# 28  https://avatars.githubusercontent.com/u/101154...  ...               NaN
# 29  https://avatars.githubusercontent.com/u/101154...  ...               NaN
#
#    payload.master_branch                            payload.description  \
# 0                    NaN                                            NaN
# 1                    NaN                                            NaN
# 2                    NaN                                            NaN
# 3                    NaN                                            NaN
# 4                    NaN                                            NaN
# 5                    NaN                                            NaN
# 6                    NaN                                            NaN
# 7                    NaN                                            NaN
# 8                   main  Ironhack micamp project, real state scenario.
# 9                 master  Ironhack micamp project, real state scenario.
# 10                   NaN                                            NaN
# 11                   NaN                                            NaN
# 12                   NaN                                            NaN
# 13                   NaN                                            NaN
# 14                   NaN                                            NaN
# 15                   NaN                                            NaN
# 16                   NaN                                            NaN
# 17                   NaN                                            NaN
# 18                   NaN                                            NaN
# 19                   NaN                                            NaN
# 20                   NaN                                            NaN
# 21                   NaN                                            NaN
# 22                   NaN                                            NaN
# 23                   NaN                                            NaN
# 24                   NaN                                            NaN
# 25                   NaN                                            NaN
# 26                   NaN                                            NaN
# 27                   NaN                                            NaN
# 28                   NaN                                            NaN
# 29                   NaN                                            NaN
#
#     payload.pusher_type  payload.action      org.id  \
# 0                   NaN             NaN         NaN
# 1                   NaN             NaN         NaN
# 2                   NaN             NaN         NaN
# 3                   NaN             NaN         NaN
# 4                   NaN             NaN         NaN
# 5                   NaN             NaN         NaN
# 6                   NaN             NaN         NaN
# 7                   NaN             NaN         NaN
# 8                  user             NaN         NaN
# 9                  user             NaN         NaN
# 10                  NaN             NaN         NaN
# 11                  NaN             NaN         NaN
# 12                  NaN             NaN         NaN
# 13                  NaN             NaN         NaN
# 14                  NaN             NaN         NaN
# 15                  NaN         started         NaN
# 16                  NaN             NaN  72746426.0
# 17                  NaN             NaN         NaN
# 18                  NaN             NaN         NaN
# 19                  NaN             NaN         NaN
# 20                  NaN             NaN         NaN
# 21                  NaN             NaN         NaN
# 22                  NaN             NaN         NaN
# 23                  NaN             NaN         NaN
# 24                  NaN             NaN         NaN
# 25                  NaN             NaN         NaN
# 26                  NaN             NaN         NaN
# 27                  NaN             NaN         NaN
# 28                  NaN             NaN         NaN
# 29                  NaN             NaN         NaN
#
#                     org.login org.gravatar_id  \
# 0                         NaN             NaN
# 1                         NaN             NaN
# 2                         NaN             NaN
# 3                         NaN             NaN
# 4                         NaN             NaN
# 5                         NaN             NaN
# 6                         NaN             NaN
# 7                         NaN             NaN
# 8                         NaN             NaN
# 9                         NaN             NaN
# 10                        NaN             NaN
# 11                        NaN             NaN
# 12                        NaN             NaN
# 13                        NaN             NaN
# 14                        NaN             NaN
# 15                        NaN             NaN
# 16  student-IH-labs-and-stuff
# 17                        NaN             NaN
# 18                        NaN             NaN
# 19                        NaN             NaN
# 20                        NaN             NaN
# 21                        NaN             NaN
# 22                        NaN             NaN
# 23                        NaN             NaN
# 24                        NaN             NaN
# 25                        NaN             NaN
# 26                        NaN             NaN
# 27                        NaN             NaN
# 28                        NaN             NaN
# 29                        NaN             NaN
#
#                                               org.url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16  https://api.github.com/orgs/student-IH-labs-an...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#                                        org.avatar_url
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16  https://avatars.githubusercontent.com/u/72746426?
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
# [30 rows x 125 columns]

# %% [markdown]
# # random pointless apis

# %%
response= requests.get('https://api.agify.io?name=pau')

# %%
response.content
# Out:
# b'{"name":"pau","age":39,"count":6536}'

# %%
response= requests.get('https://api.nationalize.io?name=Pau')

# %%
response.content
# Out:
# b'{"name":"Pau","country":[{"country_id":"AR","probability":0.2668893434453841},{"country_id":"ES","probability":0.24779724796344074},{"country_id":"CL","probability":0.2146237150897371}]}'

# %%
my_json=json.loads(response.content)

# %%
my_json
# Out:
# {'name': 'Pau',
#  'country': [{'country_id': 'AR', 'probability': 0.2668893434453841},
#   {'country_id': 'ES', 'probability': 0.24779724796344074},
#   {'country_id': 'CL', 'probability': 0.2146237150897371}]}

# %%
npd=pd.DataFrame(my_json)

# %%
npd
# Out:
#   name                                            country
# 0  Pau  {'country_id': 'AR', 'probability': 0.26688934...
# 1  Pau  {'country_id': 'ES', 'probability': 0.24779724...
# 2  Pau  {'country_id': 'CL', 'probability': 0.21462371...

# %%
#what should I do if im bored
response=requests.get('https://boredapi.com/api/activity')

# %%
response.content
# Out:
# b'{"activity":"Visit a nearby museum","type":"recreational","participants":1,"price":0.2,"link":"","key":"5490351","accessibility":0.7}'

# %% [markdown]
# # international space station

# %%
#install folium on conda env

# %%
response = requests.get('http://api.open-notify.org/iss-now.json')

# %%
response.json()
# Out:
# {'timestamp': 1653401458,
#  'iss_position': {'latitude': '30.3122', 'longitude': '26.1313'},
#  'message': 'success'}

# %%
import folium

# %%
latlong=[response.json()['iss_position']['latitude'],response.json()['iss_position']['longitude']]

# %%
mappy=folium.Map(location=latlong,zoom_starts=5)
mappy
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_758b2f1528e96f5d080609a64257ecac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_758b2f1528e96f5d080609a64257ecac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_758b2f1528e96f5d080609a64257ecac = L.map(
#                 &quot;map_758b2f1528e96f5d080609a64257ecac&quot;,
#                 {
#                     center: [20.6704, 16.8076],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     zoomStarts: 5,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3a9292ffb81e94ef8755f2e723aecab5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_758b2f1528e96f5d080609a64257ecac);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
icon=folium.Icon(color='pink',
                prefix='fa',
                icon='rocket',
                icon_color='black',)

# %%
icon_data={'location':latlong, 'tooltip':'iss', 'icon':icon}

# %%
iss_marker=folium.Marker(**icon_data)

# %%
iss_marker.add_to(mappy);

# %%
mappy
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_758b2f1528e96f5d080609a64257ecac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_758b2f1528e96f5d080609a64257ecac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_758b2f1528e96f5d080609a64257ecac = L.map(
#                 &quot;map_758b2f1528e96f5d080609a64257ecac&quot;,
#                 {
#                     center: [20.6704, 16.8076],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     zoomStarts: 5,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3a9292ffb81e94ef8755f2e723aecab5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_758b2f1528e96f5d080609a64257ecac);
#
#
#             var marker_25fa3f24e4b10c6b7d5966ab0206d6ec = L.marker(
#                 [20.6704, 16.8076],
#                 {}
#             ).addTo(map_758b2f1528e96f5d080609a64257ecac);
#
#
#             var icon_ed645cd824c5b367e4de13141f79e11f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;rocket&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_25fa3f24e4b10c6b7d5966ab0206d6ec.setIcon(icon_ed645cd824c5b367e4de13141f79e11f);
#
#
#             marker_25fa3f24e4b10c6b7d5966ab0206d6ec.bindTooltip(
#                 `&lt;div&gt;
#                      iss
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9ed830ab4aaf28ed8044bb3581306b52 = L.marker(
#                 [28.242, 23.9185],
#                 {}
#             ).addTo(map_758b2f1528e96f5d080609a64257ecac);
#
#
#             var icon_514e98e0b93daf9b427d2d118f6a9083 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;rocket&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_9ed830ab4aaf28ed8044bb3581306b52.setIcon(icon_514e98e0b93daf9b427d2d118f6a9083);
#
#
#             marker_9ed830ab4aaf28ed8044bb3581306b52.bindTooltip(
#                 `&lt;div&gt;
#                      iss
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_dc50cbef678440e55a5033c08e15956e = L.marker(
#                 [30.3122, 26.1313],
#                 {}
#             ).addTo(map_758b2f1528e96f5d080609a64257ecac);
#
#
#             var icon_026b354f2cce4e9bf54bf36ecb926c3a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;rocket&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_dc50cbef678440e55a5033c08e15956e.setIcon(icon_026b354f2cce4e9bf54bf36ecb926c3a);
#
#
#             marker_dc50cbef678440e55a5033c08e15956e.bindTooltip(
#                 `&lt;div&gt;
#                      iss
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#mi casa - telefono - 41.38175704069519, 2.1355167911537882

coordinates={'lat':41.38, 'lon':2.13, 'n':10}

response = requests.get('http://api.open-notify.org/iss-pass.json', params=coordinates)

# %%
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'message': 'success',
#  'request': {'altitude': 100,
#   'datetime': 1653402068,
#   'latitude': 41.38,
#   'longitude': 2.13,
#   'passes': 10},
#  'response': [{'duration': 602, 'risetime': 1653406852},
#   {'duration': 647, 'risetime': 1653412624},
#   {'duration': 585, 'risetime': 1653418497},
#   {'duration': 582, 'risetime': 1653424365},
#   {'duration': 643, 'risetime': 1653430179},
#   {'duration': 606, 'risetime': 1653435994},
#   {'duration': 545, 'risetime': 1653490408},
#   {'duration': 654, 'risetime': 1653496134},
#   {'duration': 601, 'risetime': 1653501992},
#   {'duration': 573, 'risetime': 1653507870}]}

# %%
from datetime import datetime
datetime.fromtimestamp(1653507870)
# Out:
# datetime.datetime(2022, 5, 25, 21, 44, 30)

# %% [markdown]
# ## passing authorisation key
