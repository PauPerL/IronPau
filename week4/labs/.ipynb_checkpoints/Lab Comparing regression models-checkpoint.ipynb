# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix, accuracy_score, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
# %matplotlib inline
sns.set(rc={'figure.figsize':(12.,6.)})
sns.set_style('whitegrid')
import warnings
warnings.filterwarnings('ignore')

# %%
import sweetviz as sv

# %%
df = pd.read_csv('winequality-red.csv', sep=';')

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.duplicated().sum()
# Out:
# 240

# %%
my_report = sv.analyze(df)
my_report.show_html() # Default arguments will generate to "SWEETVIZ_REPORT.html"
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
# to simplify we could choose some columns and with the report we can choose the ones that feel like have more impact


df1 = df[['alcohol', 'volatile acidity', 'total sulfur dioxide', 'sulphates', 'citric acid', 'quality' ]]

# %%
df1
# Out:
#       alcohol  volatile acidity  total sulfur dioxide  sulphates  citric acid  \
# 0         9.4             0.700                  34.0       0.56         0.00
# 1         9.8             0.880                  67.0       0.68         0.00
# 2         9.8             0.760                  54.0       0.65         0.04
# 3         9.8             0.280                  60.0       0.58         0.56
# 4         9.4             0.700                  34.0       0.56         0.00
# ...       ...               ...                   ...        ...          ...
# 1594     10.5             0.600                  44.0       0.58         0.08
# 1595     11.2             0.550                  51.0       0.76         0.10
# 1596     11.0             0.510                  40.0       0.75         0.13
# 1597     10.2             0.645                  44.0       0.71         0.12
# 1598     11.0             0.310                  42.0       0.66         0.47
#
#       quality
# 0           5
# ...

# %%
#lets see general info
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   alcohol               1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   total sulfur dioxide  1599 non-null   float64
#  3   sulphates             1599 non-null   float64
#  4   citric acid           1599 non-null   float64
#  5   quality               1599 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 75.1 KB

# %%
#lets see the global visualization of this data
from pandas.plotting import scatter_matrix 
scatter_matrix(df1,alpha=0.2, figsize=(25,16),diagonal='kde');

# %%
df1['alcohol'].hist()
# Out:
# <AxesSubplot:>

# %%
df1['volatile acidity'].hist()
# Out:
# <AxesSubplot:>

# %%
df1['total sulfur dioxide'].hist()
# Out:
# <AxesSubplot:>

# %%
df1['sulphates'].hist()
# Out:
# <AxesSubplot:>

# %%
df1['citric acid'].hist()
# Out:
# <AxesSubplot:>

# %%
#maybe we can drop some outliers from  total sulfur dioxide, citric acid
#starting with total sulfur dioxide

df1[df1['total sulfur dioxide']>166]
#there is a big diference from ~160 to 278
# Out:
#       alcohol  volatile acidity  total sulfur dioxide  sulphates  citric acid  \
# 1079     12.3               0.3                 278.0       0.51         0.68
# 1081     12.3               0.3                 289.0       0.51         0.68
#
#       quality
# 1079        7
# 1081        7

# %%
#lets see other high values
df1[df1['total sulfur dioxide']>146]
# Out:
#       alcohol  volatile acidity  total sulfur dioxide  sulphates  citric acid  \
# 15        9.2             0.620                 148.0       0.93         0.19
# 109       9.3             0.785                 153.0       0.69         0.52
# 354      11.9             0.210                 165.0       0.59         0.40
# 515       9.3             0.655                 151.0       1.14         0.49
# 591      11.5             0.390                 149.0       0.50         0.49
# 636       9.4             0.880                 147.0       0.53         0.28
# 649      11.3             0.420                 148.0       0.57         0.27
# 651      11.2             0.880                 155.0       0.67         0.25
# 672       9.5             1.240                 151.0       0.53         0.34
# 684       9.4             0.980                 152.0       0.48         0.32
# 1079     12.3             0.300                 278.0       0.51         0.68
# ...

# %%
#as i ve been watching, the outliers dont outlie on every value but only in some so maybe we shouldnt touch them

df1[df1['total sulfur dioxide']>146]['alcohol'].hist()
# Out:
# <AxesSubplot:>

# %% [raw]
# df1[df1['total sulfur dioxide']>146]['volatile acidity'].hist()

# %% [raw]
# df1[df1['total sulfur dioxide']>146]['sulphates'].hist()

# %% [raw]
# df1[df1['total sulfur dioxide']>146]['citric acid'].hist()

# %%
#now look at citric acid
df1[df1['citric acid']>0.8]
# Out:
#      alcohol  volatile acidity  total sulfur dioxide  sulphates  citric acid  \
# 151      9.4              0.52                  69.0        2.0          1.0
#
#      quality
# 151        4

# %%
#lets see other high values
df1[df1['citric acid']>0.7]

#it looks like this outliner is the same outliner that we could se on the sulphates, maybe we should drop it
#or maybe its a good pari indicator fro quality
# Out:
#       alcohol  volatile acidity  total sulfur dioxide  sulphates  citric acid  \
# 151       9.4             0.520                  69.0       2.00         1.00
# 205      10.8             0.300                  28.0       0.77         0.74
# 206      10.8             0.300                  28.0       0.77         0.74
# 258       9.4             0.410                  45.0       1.26         0.76
# 353      13.0             0.530                  77.0       0.77         0.79
# 375      11.8             0.540                  15.0       0.83         0.71
# 395      13.0             0.370                  38.0       0.60         0.76
# 437      11.2             0.450                  22.0       0.66         0.73
# 440       9.8             0.310                  29.0       0.82         0.72
# 442      11.2             0.685                  43.0       0.68         0.76
# 501      12.0             0.440                  76.0       0.85         0.73
# ...

# %%
#maybe we should start spliting the data scaling and preparing it to get a model

y=df['quality']
X=df.drop(['quality'],axis=1)
