# %%
pwd
# Out:
# 'C:\\Users\\Krop\\Documents\\Ironhack\\LabsCamp\\IronPau\\w1day3'

# %%
import pandas as pd
df1 = pd.read_csv('csv_files\\file1.csv')
df1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df2 = pd.read_csv('csv_files\\file2.csv')
df2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
df3 = pd.read_csv('csv_files\\file3.csv')
df3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
print("File1: ")
print(df1.shape)
print("File2: ")
print(df2.shape)
print("File3: ")
print(df3.shape)
# Out:
# File1:
# (4008, 11)
# File2:
# (996, 11)
# File3:
# (7070, 11)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4008 entries, 0 to 4007
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Customer                   1071 non-null   object
#  1   ST                         1071 non-null   object
#  2   GENDER                     954 non-null    object
#  3   Education                  1071 non-null   object
#  4   Customer Lifetime Value    1068 non-null   object
#  5   Income                     1071 non-null   float64
#  6   Monthly Premium Auto       1071 non-null   float64
#  7   Number of Open Complaints  1071 non-null   object
#  8   Policy Type                1071 non-null   object
#  9   Vehicle Class              1071 non-null   object
#  10  Total Claim Amount         1071 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 344.6+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 996 entries, 0 to 995
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Customer                   996 non-null    object
#  1   ST                         996 non-null    object
#  2   GENDER                     991 non-null    object
#  3   Education                  996 non-null    object
#  4   Customer Lifetime Value    992 non-null    object
#  5   Income                     996 non-null    int64
#  6   Monthly Premium Auto       996 non-null    int64
#  7   Number of Open Complaints  996 non-null    object
#  8   Total Claim Amount         996 non-null    float64
#  9   Policy Type                996 non-null    object
#  10  Vehicle Class              996 non-null    object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 85.7+ KB

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7070 entries, 0 to 7069
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Customer                   7070 non-null   object
#  1   State                      7070 non-null   object
#  2   Customer Lifetime Value    7070 non-null   float64
#  3   Education                  7070 non-null   object
#  4   Gender                     7070 non-null   object
#  5   Income                     7070 non-null   int64
#  6   Monthly Premium Auto       7070 non-null   int64
#  7   Number of Open Complaints  7070 non-null   int64
#  8   Policy Type                7070 non-null   object
#  9   Total Claim Amount         7070 non-null   float64
#  10  Vehicle Class              7070 non-null   object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 607.7+ KB

# %%
print(df1.columns)
print(df2.columns)
print(df3.columns)
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
coldf1 = []

for i in range(len(df1.columns)):
    coldf1.append(df1.columns[i].lower())
    
print(coldf1)
# Out:
# ['customer', 'st', 'gender', 'education', 'customer lifetime value', 'income', 'monthly premium auto', 'number of open complaints', 'policy type', 'vehicle class', 'total claim amount']

# %%
coldf2 = []

for i in range(len(df2.columns)):
    coldf2.append(df2.columns[i].lower())
    
print(coldf2)
# Out:
# ['customer', 'st', 'gender', 'education', 'customer lifetime value', 'income', 'monthly premium auto', 'number of open complaints', 'total claim amount', 'policy type', 'vehicle class']

# %%
coldf3 = []

for i in range(len(df3.columns)):
    coldf3.append(df3.columns[i].lower())
    
print(coldf3)
# Out:
# ['customer', 'state', 'customer lifetime value', 'education', 'gender', 'income', 'monthly premium auto', 'number of open complaints', 'policy type', 'total claim amount', 'vehicle class']

# %%
df1.columns = coldf1 
df1.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'vehicle class', 'total claim amount'],
#       dtype='object')

# %%
df2.columns = coldf2 
df2.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'total claim amount', 'policy type', 'vehicle class'],
#       dtype='object')

# %%
df3.columns = coldf3
df3.columns
# Out:
# Index(['customer', 'state', 'customer lifetime value', 'education', 'gender',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'total claim amount', 'vehicle class'],
#       dtype='object')

# %%
print(df1.columns)
print(df2.columns)
print(df3.columns)
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'vehicle class', 'total claim amount'],
#       dtype='object')
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'total claim amount', 'policy type', 'vehicle class'],
#       dtype='object')
# Index(['customer', 'state', 'customer lifetime value', 'education', 'gender',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'total claim amount', 'vehicle class'],
#       dtype='object')

# %%
#prueba para ver como cambiar las columnas de sitio
df1alt = df1[['customer', 'st', 'gender', 'education', 'customer lifetime value',
       'income', 'monthly premium auto', 'number of open complaints',
       'policy type', 'vehicle class', 'total claim amount']]
df1alt.head()
# Out:
#   customer          st gender             education customer lifetime value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     income  monthly premium auto number of open complaints     policy type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    vehicle class  total claim amount
# ...

# %%
df2alt = df2[['customer', 'st', 'gender', 'education', 'customer lifetime value',
       'income', 'monthly premium auto', 'number of open complaints',
       'policy type', 'vehicle class', 'total claim amount']]
df2alt.head()
# Out:
#   customer          st gender education customer lifetime value  income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    monthly premium auto number of open complaints     policy type  \
# 0                    88                    1/0/00   Personal Auto
# 1                   114                    1/0/00    Special Auto
# 2                   112                    1/0/00   Personal Auto
# 3                   214                    1/1/00   Personal Auto
# 4                    94                    1/0/00  Corporate Auto
#
#    vehicle class  total claim amount
# 0  Four-Door Car               633.6
# 1            SUV               547.2
# ...

# %%
df3alt = df3[['customer', 'state', 'gender', 'education', 'customer lifetime value',
       'income', 'monthly premium auto', 'number of open complaints',
       'policy type', 'vehicle class', 'total claim amount']]

df3alt.head()
# Out:
#   customer       state gender             education  customer lifetime value  \
# 0  SA25987  Washington      M  High School or Below              3479.137523
# 1  TB86706     Arizona      M                Master              2502.637401
# 2  ZL73902      Nevada      F              Bachelor              3265.156348
# 3  KX23516  California      F  High School or Below              4455.843406
# 4  FN77294  California      M  High School or Below              7704.958480
#
#    income  monthly premium auto  number of open complaints    policy type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    vehicle class  total claim amount
# ...

# %%
df1alt.rename(columns = {'st':'state'}, inplace = True )
df2alt.rename(columns = {'st':'state'}, inplace = True )
df1alt.head()
# Out:
#   customer       state gender             education customer lifetime value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     income  monthly premium auto number of open complaints     policy type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    vehicle class  total claim amount
# ...

# %%
df2alt.head()
# Out:
#   customer       state gender education customer lifetime value  income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    monthly premium auto number of open complaints     policy type  \
# 0                    88                    1/0/00   Personal Auto
# 1                   114                    1/0/00    Special Auto
# 2                   112                    1/0/00   Personal Auto
# 3                   214                    1/1/00   Personal Auto
# 4                    94                    1/0/00  Corporate Auto
#
#    vehicle class  total claim amount
# 0  Four-Door Car               633.6
# 1            SUV               547.2
# ...

# %%
df3alt.head()
# Out:
#   customer       state gender             education  customer lifetime value  \
# 0  SA25987  Washington      M  High School or Below              3479.137523
# 1  TB86706     Arizona      M                Master              2502.637401
# 2  ZL73902      Nevada      F              Bachelor              3265.156348
# 3  KX23516  California      F  High School or Below              4455.843406
# 4  FN77294  California      M  High School or Below              7704.958480
#
#    income  monthly premium auto  number of open complaints    policy type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    vehicle class  total claim amount
# ...

# %%
df1alt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4008 entries, 0 to 4007
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   1071 non-null   object
#  1   state                      1071 non-null   object
#  2   gender                     954 non-null    object
#  3   education                  1071 non-null   object
#  4   customer lifetime value    1068 non-null   object
#  5   income                     1071 non-null   float64
#  6   monthly premium auto       1071 non-null   float64
#  7   number of open complaints  1071 non-null   object
#  8   policy type                1071 non-null   object
#  9   vehicle class              1071 non-null   object
#  10  total claim amount         1071 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 344.6+ KB

# %%
df2alt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 996 entries, 0 to 995
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   996 non-null    object
#  1   state                      996 non-null    object
#  2   gender                     991 non-null    object
#  3   education                  996 non-null    object
#  4   customer lifetime value    992 non-null    object
#  5   income                     996 non-null    int64
#  6   monthly premium auto       996 non-null    int64
#  7   number of open complaints  996 non-null    object
#  8   policy type                996 non-null    object
#  9   vehicle class              996 non-null    object
#  10  total claim amount         996 non-null    float64
# dtypes: float64(1), int64(2), object(8)
# memory usage: 85.7+ KB

# %%
df3alt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7070 entries, 0 to 7069
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   7070 non-null   object
#  1   state                      7070 non-null   object
#  2   gender                     7070 non-null   object
#  3   education                  7070 non-null   object
#  4   customer lifetime value    7070 non-null   float64
#  5   income                     7070 non-null   int64
#  6   monthly premium auto       7070 non-null   int64
#  7   number of open complaints  7070 non-null   int64
#  8   policy type                7070 non-null   object
#  9   vehicle class              7070 non-null   object
#  10  total claim amount         7070 non-null   float64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 607.7+ KB

# %%
df_all = pd.concat([df1alt, df2alt, df3alt], axis = 0)

# %%
df_all.reset_index(drop=True, inplace=True)
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12074 entries, 0 to 12073
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   9137 non-null   object
#  1   state                      9137 non-null   object
#  2   gender                     9015 non-null   object
#  3   education                  9137 non-null   object
#  4   customer lifetime value    9130 non-null   object
#  5   income                     9137 non-null   float64
#  6   monthly premium auto       9137 non-null   float64
#  7   number of open complaints  9137 non-null   object
#  8   policy type                9137 non-null   object
#  9   vehicle class              9137 non-null   object
#  10  total claim amount         9137 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 1.0+ MB

# %%
df_all
# Out:
#       customer       state gender             education  \
# 0      RB50392  Washington    NaN                Master
# 1      QZ44356     Arizona      F              Bachelor
# 2      AI49188      Nevada      F              Bachelor
# 3      WW63253  California      M              Bachelor
# 4      GA49547  Washington      M  High School or Below
# ...        ...         ...    ...                   ...
# 12069  LA72316  California      M              Bachelor
# 12070  PK87824  California      F               College
# 12071  TD14365  California      M              Bachelor
# 12072  UP19263  California      M               College
# 12073  Y167826  California      M               College
#
#       customer lifetime value   income  monthly premium auto  \
# 0                         NaN      0.0                1000.0
# 1                  697953.59%      0.0                  94.0
# 2                 1288743.17%  48767.0                 108.0
# ...

# %% [raw]
# income, monthly premium auto, total claim amount are numerical columns
#
# and customer lifetime value and  number of open complaints should be numerical columns

# %% [raw]
# customer, state, gender,  education,  policy type and vehicle class are categorical

# %%
df_all.drop(['education', 'number of open complaints'], axis = 1, inplace = True) 
df_all
# Out:
#       customer       state gender customer lifetime value   income  \
# 0      RB50392  Washington    NaN                     NaN      0.0
# 1      QZ44356     Arizona      F              697953.59%      0.0
# 2      AI49188      Nevada      F             1288743.17%  48767.0
# 3      WW63253  California      M              764586.18%      0.0
# 4      GA49547  Washington      M              536307.65%  36357.0
# ...        ...         ...    ...                     ...      ...
# 12069  LA72316  California      M             23405.98798  71941.0
# 12070  PK87824  California      F             3096.511217  21604.0
# 12071  TD14365  California      M             8163.890428      0.0
# 12072  UP19263  California      M             7524.442436  21941.0
# 12073  Y167826  California      M             2611.836866      0.0
#
#        monthly premium auto     policy type  vehicle class  total claim amount
# 0                    1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
#lets test some things
dfblob = df_all

# %% [raw]
# #dfblob['customer lifetime value']=dfblob[['customer lifetime value']].totype()
#
# pd.to_numeric(dfblob['customer lifetime value'])

# %% [raw]
# dfblob['customer lifetime value'] = dfblob['customer lifetime value'].str.strip('%').astype(float)/100  #df[0] = df[0].str.strip()

# %% [raw]
# dfblob['customer lifetime value'] = dfblob['customer lifetime value'].str.strip('%')

# %% [raw]
# dfblob

# %% [raw]
# for i in dfblob['customer lifetime value']:
#     if ('%'in i ):

# %% [markdown]
# Vamos a limpiar las columnas antes de concatenarlas

# %% [raw]
# df1alt['customer lifetime value'] = df1alt['customer lifetime value'].str.strip('%').astype(float)/100
# df1alt

# %% [raw]
# df2alt['customer lifetime value'] = df2alt['customer lifetime value'].str.strip('%').astype(float)/100
# df2alt

# %% [raw]
# df3alt['customer lifetime value'] = df3alt['customer lifetime value'].astype(float)/100
# df3alt

# %%
#if there is a % 
#then strip % sign 
#then *100
#then convert to float

# %% [raw]
# #loop from federica to clean the data
# new_customer_lifetime_values = []
# for i in range (len(df_all["customer lifetime value"])):
#     entry = df_all["customer lifetime value"][i]
#     if type (df_all["customer lifetime value"][i]) == str:
#         if entry[-1] == "%":
#             new_customer_lifetime_values.append(entry[:-1])
#         else:
#             new_customer_lifetime_values.append(entry)
#     else:
#         new_customer_lifetime_values.append(entry)

# %% [raw]
# #mor code from federica
# #convert all the entries of the new_customer_lifetime_values in float and multiply them by 100 and add the new variable to the dataframe
# new_customer_lifetime_values_float =[]
# for i in range(len(new_customer_lifetime_values)):
#     entry = new_customer_lifetime_values[i]
#     if type(new_customer_lifetime_values[i]) == str:
#         entry = float(entry)
#         new_customer_lifetime_values_float.append(entry*100)
#     else:
#         new_customer_lifetime_values_float.append(entry*100)

# %% [raw]
# df_all.insert(coldf1-2,'new_customer_lifetime_values', new_customer_lifetime_values_float)

# %% [raw]
# #quitar los customers que no tienen nombre codigo de la profe sean
#
# df_all = df_all.dropna(subset=["customer"])

# %%
#to see all the customers with income 0
df_gt0=df_all[df_all["income"]<=0]
df_gt0
# Out:
#       customer       state gender customer lifetime value  income  \
# 0      RB50392  Washington    NaN                     NaN     0.0
# 1      QZ44356     Arizona      F              697953.59%     0.0
# 3      WW63253  California      M              764586.18%     0.0
# 7      CF85061     Arizona      M              721610.03%     0.0
# 10     SX51350  California      M              473899.20%     0.0
# ...        ...         ...    ...                     ...     ...
# 12063  WZ45103  California      F             5678.050167     0.0
# 12065  RX91025  California      M               19872.262     0.0
# 12066  AC13887  California      M             4628.995325     0.0
# 12071  TD14365  California      M             8163.890428     0.0
# 12073  Y167826  California      M             2611.836866     0.0
#
#        monthly premium auto     policy type  vehicle class  total claim amount
# 0                    1000.0   Personal Auto  Four-Door Car            2.704934
# ...
