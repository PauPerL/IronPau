# %% [markdown]
# ### Gender and racial bias in computer vision
# - https://thegoodai.co/2021/04/14/gender-and-racial-bias-in-computer-vision/
#
# From here we can link to some other articles like:
#
# https://www.wired.com/story/ai-sees-man-thinks-official-woman-smile/
#
# http://gendershades.org/
#
# https://www.ecva.net/papers/eccv_2018/papers_ECCV/papers/Lisa_Anne_Hendricks_Women_also_Snowboard_ECCV_2018_paper.pdf
#
# And it's interesting to see how the machines have learnt to use the context to determine the gender instead trying to figure out from the gender expresion of the persons in the image and that leads to the machine asuming incorrectly that in sports on computer enviroments the persons shown are men instead of trying to figure out and finding that there is also women.

# %%
#using the caption: 'A view of home office with one computer screen'

# %matplotlib inline
from IPython.display import Image
Image('genimg.png')

# %% [markdown]
# ### Image Recognition: Dogs vs Cats!
# - https://thedatafrog.com/en/articles/dogs-vs-cats/
#
# He got the data, then cleaned as there were some images that were not dogs nor cats like cartoons or unrelated images, then started using keras and looked that the labels were correctly set, split the data, do a convolutional NN etc.
