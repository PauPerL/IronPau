# %% [markdown]
# Case study help. First time working on data.

# %%
import pandas as pd

# %%
import numpy as np

# %%
health1 = pd.read_csv('file1.csv')

# %%
health1
# Out:
#       CONTROLN STATE GENDER      HV1  IC1    IC4  HVP1    IC5  POBC1  POBC2  \
# 0        44060    FL      M   AAA896  392  520.0     7  21975      6     16
# 1        96093    IL      M   537.00  365  473.0     0  19387      1     89
# 2        43333    FL      F   725.00  301  436.0     3  18837     11     17
# 3        21885    NC      M  AAA1095  401  413.0     7  14014      1     74
# 4       190108    FL      F   995.00  252  348.0     0  17991      5      6
# ...        ...   ...    ...      ...  ...    ...   ...    ...    ...    ...
# 1002    114721    OK    NaN     1040  472  656.0     0  26962      2     56
# 1003    149152    CA      M     4507  842  962.0    95  54642     17     50
# 1004       959    IA      F      586  349  465.0     1  15304      1     77
# 1005    179563    WA   male      842  420  494.0     2  12894     41     24
# 1006     41243    FL      F      556  246  330.0     0  10272      2     56
#
# ...

# %%
health1.describe()
# Out:
#             CONTROLN          IC1          IC4         HVP1        POBC1  \
# count    1007.000000  1007.000000  1006.000000  1007.000000  1007.000000
# mean    98913.029791   352.015889   445.059642    16.261172     6.847071
# std     58306.879885   173.937638   178.115476    29.464477     9.333689
# min        71.000000     0.000000     0.000000     0.000000     0.000000
# 25%     44930.500000   238.500000   325.000000     0.000000     1.000000
# 50%    101113.000000   319.000000   406.000000     1.000000     4.000000
# 75%    151559.000000   421.500000   527.000000    14.000000     9.000000
# max    191779.000000  1500.000000  1263.000000    99.000000    73.000000
#
#              POBC2          IC2          IC3      AVGGIFT        TCODE  \
# count  1007.000000  1006.000000  1007.000000  1007.000000  1007.000000
# mean     55.630586   401.658052   400.022840    11.863404    37.747766
# std      21.593999   182.024618   168.901139     7.829965   213.010617
# ...

# %%
health1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 17 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   CONTROLN  1007 non-null   int64
#  1   STATE     1007 non-null   object
#  2   GENDER    967 non-null    object
#  3   HV1       1005 non-null   object
#  4   IC1       1007 non-null   int64
#  5   IC4       1006 non-null   float64
#  6   HVP1      1007 non-null   int64
#  7   IC5       1007 non-null   object
#  8   POBC1     1007 non-null   int64
#  9   POBC2     1007 non-null   int64
#  10  IC2       1006 non-null   float64
#  11  IC3       1007 non-null   int64
#  12  AVGGIFT   1007 non-null   float64
#  13  TCODE     1007 non-null   int64
#  14  DOB       1007 non-null   int64
#  15  DOMAIN    1007 non-null   object
#  16  TARGET_D  1007 non-null   float64
# dtypes: float64(4), int64(8), object(5)
# memory usage: 133.9+ KB

# %%
health1.head()
# Out:
#    CONTROLN STATE GENDER      HV1  IC1    IC4  HVP1    IC5  POBC1  POBC2  \
# 0     44060    FL      M   AAA896  392  520.0     7  21975      6     16
# 1     96093    IL      M   537.00  365  473.0     0  19387      1     89
# 2     43333    FL      F   725.00  301  436.0     3  18837     11     17
# 3     21885    NC      M  AAA1095  401  413.0     7  14014      1     74
# 4    190108    FL      F   995.00  252  348.0     0  17991      5      6
#
#      IC2  IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# 0  430.0  466  28.000000      1  1901     C2     100.0
# 1  415.0  410   5.666667      0     0     T2       7.0
# 2  340.0  361   4.111111      0  2501     C2       5.0
# 3  407.0  399  27.277778      0  2208     T2      38.0
# 4  280.0  316   6.000000     28     0     C2       5.0

# %%
health1.head(10)
# Out:
#    CONTROLN STATE  GENDER      HV1  IC1    IC4  HVP1    IC5  POBC1  POBC2  \
# 0     44060    FL       M   AAA896  392  520.0     7  21975      6     16
# 1     96093    IL       M   537.00  365  473.0     0  19387      1     89
# 2     43333    FL       F   725.00  301  436.0     3  18837     11     17
# 3     21885    NC       M  AAA1095  401  413.0     7  14014      1     74
# 4    190108    FL       F   995.00  252  348.0     0  17991      5      6
# 5    100640    IL       M   764.00  457  501.0     1  16022      2     75
# 6     18581    NC  female   775.00  318  419.0     5  13491      0     73
# 7    119038    TX       M   890.00  519  560.0     0  17872      2     46
# 8    173223    CA       F      NaN  184  250.0     0   8708      2     63
# 9    157988    CA       F  AAA2294  593  617.0    61  17838      7     62
#
#      IC2  IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# 0  430.0  466  28.000000      1  1901     C2     100.0
# ...

# %%
health1.tail(10)
# Out:
#       CONTROLN STATE GENDER   HV1  IC1    IC4  HVP1    IC5  POBC1  POBC2  \
# 997      57151    KY      F   875  311  326.0     0   7746      3     29
# 998      71425    MI      M   713  300  364.0     0  16833      2     88
# 999     127823    TX      F   258   64   74.0     0   4236      0     94
# 1000    150739    CA      U  1951  556  625.0    44  17208     10     66
# 1001     41384    FL      F   556  318  352.0     0  11779     16     22
# 1002    114721    OK    NaN  1040  472  656.0     0  26962      2     56
# 1003    149152    CA      M  4507  842  962.0    95  54642     17     50
# 1004       959    IA      F   586  349  465.0     1  15304      1     77
# 1005    179563    WA   male   842  420  494.0     2  12894     41     24
# 1006     41243    FL      F   556  246  330.0     0  10272      2     56
#
#          IC2  IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# 997    326.0  326  15.900000      0  3601     R1      26.0
# ...

# %%
health1["GENDER"].unique()
# Out:
# array(['M', 'F', 'female', 'Male', nan, 'U', 'J', 'male', 'Female',
#        'feamale'], dtype=object)

# %%
health1.columns
# Out:
# Index(['CONTROLN', 'STATE', 'GENDER', 'HV1', 'IC1', 'IC4', 'HVP1', 'IC5',
#        'POBC1', 'POBC2', 'IC2', 'IC3', 'AVGGIFT', 'TCODE', 'DOB', 'DOMAIN',
#        'TARGET_D'],
#       dtype='object')

# %%
colh = []

for i in range(len(health1.columns)):
    colh.append(health1.columns[i].lower()) #usamos un for para llenar la nueva lista y ponerla en minusculas 

print(colh)
# Out:
# ['controln', 'state', 'gender', 'hv1', 'ic1', 'ic4', 'hvp1', 'ic5', 'pobc1', 'pobc2', 'ic2', 'ic3', 'avggift', 'tcode', 'dob', 'domain', 'target_d']

# %%
health1.columns = colh 
health1.columns
# Out:
# Index(['controln', 'state', 'gender', 'hv1', 'ic1', 'ic4', 'hvp1', 'ic5',
#        'pobc1', 'pobc2', 'ic2', 'ic3', 'avggift', 'tcode', 'dob', 'domain',
#        'target_d'],
#       dtype='object')

# %%
health1
# Out:
#       controln state gender      hv1  ic1    ic4  hvp1    ic5  pobc1  pobc2  \
# 0        44060    FL      M   AAA896  392  520.0     7  21975      6     16
# 1        96093    IL      M   537.00  365  473.0     0  19387      1     89
# 2        43333    FL      F   725.00  301  436.0     3  18837     11     17
# 3        21885    NC      M  AAA1095  401  413.0     7  14014      1     74
# 4       190108    FL      F   995.00  252  348.0     0  17991      5      6
# ...        ...   ...    ...      ...  ...    ...   ...    ...    ...    ...
# 1002    114721    OK    NaN     1040  472  656.0     0  26962      2     56
# 1003    149152    CA      M     4507  842  962.0    95  54642     17     50
# 1004       959    IA      F      586  349  465.0     1  15304      1     77
# 1005    179563    WA   male      842  420  494.0     2  12894     41     24
# 1006     41243    FL      F      556  246  330.0     0  10272      2     56
#
# ...

# %%
hlth1 = health1.drop(["controln", "pobc2"], axis = 1) #axis 1 refers to columns and 0 son filas
hlth1
# Out:
#      state gender      hv1  ic1    ic4  hvp1    ic5  pobc1     ic2  ic3  \
# 0       FL      M   AAA896  392  520.0     7  21975      6   430.0  466
# 1       IL      M   537.00  365  473.0     0  19387      1   415.0  410
# 2       FL      F   725.00  301  436.0     3  18837     11   340.0  361
# 3       NC      M  AAA1095  401  413.0     7  14014      1   407.0  399
# 4       FL      F   995.00  252  348.0     0  17991      5   280.0  316
# ...    ...    ...      ...  ...    ...   ...    ...    ...     ...  ...
# 1002    OK    NaN     1040  472  656.0     0  26962      2   609.0  579
# 1003    CA      M     4507  842  962.0    95  54642     17  1004.0  893
# 1004    IA      F      586  349  465.0     1  15304      1   413.0  404
# 1005    WA   male      842  420  494.0     2  12894     41   419.0  476
# 1006    FL      F      556  246  330.0     0  10272      2   277.0  292
#
#         avggift  tcode   dob domain  target_d
# 0     28.000000      1  1901     C2     100.0
# ...

# %%
health1
# Out:
#       controln state gender      hv1  ic1    ic4  hvp1    ic5  pobc1  pobc2  \
# 0        44060    FL      M   AAA896  392  520.0     7  21975      6     16
# 1        96093    IL      M   537.00  365  473.0     0  19387      1     89
# 2        43333    FL      F   725.00  301  436.0     3  18837     11     17
# 3        21885    NC      M  AAA1095  401  413.0     7  14014      1     74
# 4       190108    FL      F   995.00  252  348.0     0  17991      5      6
# ...        ...   ...    ...      ...  ...    ...   ...    ...    ...    ...
# 1002    114721    OK    NaN     1040  472  656.0     0  26962      2     56
# 1003    149152    CA      M     4507  842  962.0    95  54642     17     50
# 1004       959    IA      F      586  349  465.0     1  15304      1     77
# 1005    179563    WA   male      842  420  494.0     2  12894     41     24
# 1006     41243    FL      F      556  246  330.0     0  10272      2     56
#
# ...

# %%
hlth1.dtypes
# Out:
# state        object
# gender       object
# hv1          object
# ic1           int64
# ic4         float64
# hvp1          int64
# ic5          object
# pobc1         int64
# ic2         float64
# ic3           int64
# avggift     float64
# tcode         int64
# dob           int64
# domain       object
# target_d    float64
# dtype: object

# %%
hlth1["hv1"].unique()
# Out:
# array(['AAA896', '537.00', '725.00', 'AAA1095', '995.00', '764.00',
#        '775.00', '890.00', nan, 'AAA2294', '1569', '3515', '1026', '0',
#        '376', '890', '1513', '948', '258', '1951', '556', '1040', '603',
#        '526', '717', '1011', '1063', '291', '1538', '592', '871', '403',
#        '715', '2346', '559', '596', '706', '878', '1275', '2362', '718',
#        '2531', '2089', '765', '832', '1458', '1590', '613', '477', '424',
#        '383', '688', '3500', '2143', '625', '1560', '716', '1247', '611',
#        '1431', '1089', '435', '1409', '647', '415', '492', '1043', '3668',
#        '3491', '192', '824', '428', '417', '399', '2377', '2016', '933',
#        '619', '3303', '960', '1236', '473', '1055', '1509', '1953', '927',
#        '2098', '5209', '476', '1515', '2158', '1110', '581', '563', '740',
#        '516', '575', '2357', '645', '825', '531', '195', '423', '2725',
#        '359', '1373', '1439', '889', '1993', '618', '3259', '151', '892',
# ...

# %%
newnames = {"hv1":"medianhv", "ic5":"pcapinc"} #hacemos un diccionario con antiguos y nuevos nombres

# %%
hlth1.rename(columns = newnames, inplace = True ) #hacemos el canvio de nombres con el diccionario

# %%
hlth1
# Out:
#      state gender medianhv  ic1    ic4  hvp1 pcapinc  pobc1     ic2  ic3  \
# 0       FL      M   AAA896  392  520.0     7   21975      6   430.0  466
# 1       IL      M   537.00  365  473.0     0   19387      1   415.0  410
# 2       FL      F   725.00  301  436.0     3   18837     11   340.0  361
# 3       NC      M  AAA1095  401  413.0     7   14014      1   407.0  399
# 4       FL      F   995.00  252  348.0     0   17991      5   280.0  316
# ...    ...    ...      ...  ...    ...   ...     ...    ...     ...  ...
# 1002    OK    NaN     1040  472  656.0     0   26962      2   609.0  579
# 1003    CA      M     4507  842  962.0    95   54642     17  1004.0  893
# 1004    IA      F      586  349  465.0     1   15304      1   413.0  404
# 1005    WA   male      842  420  494.0     2   12894     41   419.0  476
# 1006    FL      F      556  246  330.0     0   10272      2   277.0  292
#
#         avggift  tcode   dob domain  target_d
# ...

# %%
hlth1["medianhv"].astype("float", errors = "ignore") #intentamos convertir a float pero falla
# Out:
# 0        AAA896
# 1        537.00
# 2        725.00
# 3       AAA1095
# 4        995.00
#          ...
# 1002       1040
# 1003       4507
# 1004        586
# 1005        842
# 1006        556
# Name: medianhv, Length: 1007, dtype: object

# %%
hlth1.dtypes
# Out:
# state        object
# gender       object
# medianhv     object
# ic1           int64
# ic4         float64
# hvp1          int64
# pcapinc      object
# pobc1         int64
# ic2         float64
# ic3           int64
# avggift     float64
# tcode         int64
# dob           int64
# domain       object
# target_d    float64
# dtype: object

# %%
hlth1["medianhv"] = pd.to_numeric(hlth1["medianhv"], errors = "coerce") #estamos obligando a que sean numeros y no object

# %%
hlth1
# Out:
#      state gender  medianhv  ic1    ic4  hvp1 pcapinc  pobc1     ic2  ic3  \
# 0       FL      M       NaN  392  520.0     7   21975      6   430.0  466
# 1       IL      M     537.0  365  473.0     0   19387      1   415.0  410
# 2       FL      F     725.0  301  436.0     3   18837     11   340.0  361
# 3       NC      M       NaN  401  413.0     7   14014      1   407.0  399
# 4       FL      F     995.0  252  348.0     0   17991      5   280.0  316
# ...    ...    ...       ...  ...    ...   ...     ...    ...     ...  ...
# 1002    OK    NaN    1040.0  472  656.0     0   26962      2   609.0  579
# 1003    CA      M    4507.0  842  962.0    95   54642     17  1004.0  893
# 1004    IA      F     586.0  349  465.0     1   15304      1   413.0  404
# 1005    WA   male     842.0  420  494.0     2   12894     41   419.0  476
# 1006    FL      F     556.0  246  330.0     0   10272      2   277.0  292
#
#         avggift  tcode   dob domain  target_d
# ...

# %%
hlth1["pcapinc"] = pd.to_numeric(hlth1["pcapinc"], errors = "coerce")

# %%
hlth1
# Out:
#      state gender  medianhv  ic1    ic4  hvp1  pcapinc  pobc1     ic2  ic3  \
# 0       FL      M       NaN  392  520.0     7  21975.0      6   430.0  466
# 1       IL      M     537.0  365  473.0     0  19387.0      1   415.0  410
# 2       FL      F     725.0  301  436.0     3  18837.0     11   340.0  361
# 3       NC      M       NaN  401  413.0     7  14014.0      1   407.0  399
# 4       FL      F     995.0  252  348.0     0  17991.0      5   280.0  316
# ...    ...    ...       ...  ...    ...   ...      ...    ...     ...  ...
# 1002    OK    NaN    1040.0  472  656.0     0  26962.0      2   609.0  579
# 1003    CA      M    4507.0  842  962.0    95  54642.0     17  1004.0  893
# 1004    IA      F     586.0  349  465.0     1  15304.0      1   413.0  404
# 1005    WA   male     842.0  420  494.0     2  12894.0     41   419.0  476
# 1006    FL      F     556.0  246  330.0     0  10272.0      2   277.0  292
#
#         avggift  tcode   dob domain  target_d
# ...

# %%
hlth1.dtypes
# Out:
# state        object
# gender       object
# medianhv    float64
# ic1           int64
# ic4         float64
# hvp1          int64
# pcapinc     float64
# pobc1         int64
# ic2         float64
# ic3           int64
# avggift     float64
# tcode         int64
# dob           int64
# domain       object
# target_d    float64
# dtype: object

# %%
hlth1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   state     1007 non-null   object
#  1   gender    967 non-null    object
#  2   medianhv  1002 non-null   float64
#  3   ic1       1007 non-null   int64
#  4   ic4       1006 non-null   float64
#  5   hvp1      1007 non-null   int64
#  6   pcapinc   1001 non-null   float64
#  7   pobc1     1007 non-null   int64
#  8   ic2       1006 non-null   float64
#  9   ic3       1007 non-null   int64
#  10  avggift   1007 non-null   float64
#  11  tcode     1007 non-null   int64
#  12  dob       1007 non-null   int64
#  13  domain    1007 non-null   object
#  14  target_d  1007 non-null   float64
# dtypes: float64(6), int64(6), object(3)
# memory usage: 118.1+ KB

# %%
hlth1["gender"] = hlth1["gender"].fillna("unknown") #sustituimos los nan por unkonw

# %%
hlth1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   state     1007 non-null   object
#  1   gender    1007 non-null   object
#  2   medianhv  1002 non-null   float64
#  3   ic1       1007 non-null   int64
#  4   ic4       1006 non-null   float64
#  5   hvp1      1007 non-null   int64
#  6   pcapinc   1001 non-null   float64
#  7   pobc1     1007 non-null   int64
#  8   ic2       1006 non-null   float64
#  9   ic3       1007 non-null   int64
#  10  avggift   1007 non-null   float64
#  11  tcode     1007 non-null   int64
#  12  dob       1007 non-null   int64
#  13  domain    1007 non-null   object
#  14  target_d  1007 non-null   float64
# dtypes: float64(6), int64(6), object(3)
# memory usage: 118.1+ KB

# %%
hlth1[hlth1["pcapinc"].isna() == True ] #aqui muestra las entradas de hlth1 que tienen NaN en "pcapinc"
# Out:
#     state gender  medianhv  ic1    ic4  hvp1  pcapinc  pobc1    ic2  ic3  \
# 14     KS      F     376.0  263  316.0     0      NaN      1  303.0  287
# 905    CO      F     552.0  194  315.0     1      NaN      9  258.0  262
# 923    CO      F     638.0  222  286.0     0      NaN     13  307.0  230
# 940    IL      F     760.0  393  510.0     2      NaN      2  451.0  441
# 970    KS      F     481.0  322  352.0     0      NaN      0  318.0  359
# 992    MO      F     322.0  190  302.0     0      NaN      0  240.0  239
#
#        avggift  tcode   dob domain  target_d
# 14   10.550000      0  2405     T2      10.0
# 905  20.000000     28  4401     C3      20.0
# 923   7.214286      2  2401     C2      13.0
# 940   6.909091      0  2101     T1       8.0
# 970   5.857143      0  1501     S2       7.0
# 992  13.416667      0  3702     R2      10.0

# %%
hlth1["gender"].value_counts()
# Out:
# F          478
# M          383
# unknown     40
# male        28
# U           23
# female      16
# feamale     11
# Male        10
# J            9
# Female       9
# Name: gender, dtype: int64

# %%
hlth1[hlth1["gender"].str.match("unknown")] #mostramos las columnas de hlth1 que tengan valor unknown en gender
# Out:
#            state   gender  medianhv  ic1    ic4  hvp1  pcapinc  pobc1    ic2  \
# 15            MI  unknown     890.0  463  523.0     1   9493.0      5  474.0
# 21            OK  unknown    1040.0  472  656.0     0  26962.0      2  609.0
# 22            AR  unknown     603.0  208  341.0     2  12038.0      1  264.0
# 54            CA  unknown    2143.0  280  373.0    63  12935.0     29  353.0
# 77          Cali  unknown    2016.0  431  497.0    51  17882.0     11  465.0
# 84            IL  unknown    1055.0  366  400.0     0  11289.0      8  462.0
# 94            FL  unknown     581.0  349  373.0     0   9667.0     19  361.0
# 130           FL  unknown    3542.0  642  843.0    76  53131.0      3  690.0
# 151           CA  unknown    3020.0  756  823.0    95  26135.0      4  765.0
# 186           IN  unknown     561.0  302  331.0     1  10873.0      0  301.0
# 195           FL  unknown     696.0  272  427.0     7  16474.0      7  357.0
# ...

# %%
median1 = hlth1["medianhv"].median()

# %%
median1
# Out:
# 786.0

# %%
hlth1["medianhv"] = hlth1["medianhv"].fillna(median1)

# %%
hlth1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   state     1007 non-null   object
#  1   gender    1007 non-null   object
#  2   medianhv  1007 non-null   float64
#  3   ic1       1007 non-null   int64
#  4   ic4       1006 non-null   float64
#  5   hvp1      1007 non-null   int64
#  6   pcapinc   1001 non-null   float64
#  7   pobc1     1007 non-null   int64
#  8   ic2       1006 non-null   float64
#  9   ic3       1007 non-null   int64
#  10  avggift   1007 non-null   float64
#  11  tcode     1007 non-null   int64
#  12  dob       1007 non-null   int64
#  13  domain    1007 non-null   object
#  14  target_d  1007 non-null   float64
# dtypes: float64(6), int64(6), object(3)
# memory usage: 118.1+ KB

# %%
median2 = hlth1["ic4"].median()
median2
# Out:
# 406.0

# %%
hlth1["ic4"] = hlth1["ic4"].fillna(median2)
hlth1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   state     1007 non-null   object
#  1   gender    1007 non-null   object
#  2   medianhv  1007 non-null   float64
#  3   ic1       1007 non-null   int64
#  4   ic4       1007 non-null   float64
#  5   hvp1      1007 non-null   int64
#  6   pcapinc   1001 non-null   float64
#  7   pobc1     1007 non-null   int64
#  8   ic2       1006 non-null   float64
#  9   ic3       1007 non-null   int64
#  10  avggift   1007 non-null   float64
#  11  tcode     1007 non-null   int64
#  12  dob       1007 non-null   int64
#  13  domain    1007 non-null   object
#  14  target_d  1007 non-null   float64
# dtypes: float64(6), int64(6), object(3)
# memory usage: 118.1+ KB

# %%
median3 = hlth1["pcapinc"].median()
median3
# Out:
# 14248.0

# %%
hlth1["pcapinc"] = hlth1["pcapinc"].fillna(median3)
hlth1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   state     1007 non-null   object
#  1   gender    1007 non-null   object
#  2   medianhv  1007 non-null   float64
#  3   ic1       1007 non-null   int64
#  4   ic4       1007 non-null   float64
#  5   hvp1      1007 non-null   int64
#  6   pcapinc   1007 non-null   float64
#  7   pobc1     1007 non-null   int64
#  8   ic2       1006 non-null   float64
#  9   ic3       1007 non-null   int64
#  10  avggift   1007 non-null   float64
#  11  tcode     1007 non-null   int64
#  12  dob       1007 non-null   int64
#  13  domain    1007 non-null   object
#  14  target_d  1007 non-null   float64
# dtypes: float64(6), int64(6), object(3)
# memory usage: 118.1+ KB

# %%
median4 = hlth1["ic2"].median()
median4
# Out:
# 364.5

# %%
hlth1["ic2"] = hlth1["ic2"].fillna(median4)
hlth1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   state     1007 non-null   object
#  1   gender    1007 non-null   object
#  2   medianhv  1007 non-null   float64
#  3   ic1       1007 non-null   int64
#  4   ic4       1007 non-null   float64
#  5   hvp1      1007 non-null   int64
#  6   pcapinc   1007 non-null   float64
#  7   pobc1     1007 non-null   int64
#  8   ic2       1007 non-null   float64
#  9   ic3       1007 non-null   int64
#  10  avggift   1007 non-null   float64
#  11  tcode     1007 non-null   int64
#  12  dob       1007 non-null   int64
#  13  domain    1007 non-null   object
#  14  target_d  1007 non-null   float64
# dtypes: float64(6), int64(6), object(3)
# memory usage: 118.1+ KB

# %%
hlth1.query('gender == "F" & state == "CO" & pcapinc >= 15000') #mostrar las que cumplen condiciones
# Out:
#     state gender  medianhv  ic1    ic4  hvp1  pcapinc  pobc1    ic2  ic3  \
# 152    CO      F     431.0  258  541.0     0  25828.0      3  342.0  386
# 493    CO      F     593.0  256  399.0     0  37734.0      7  298.0  336
# 581    CO      F     947.0  300  469.0     3  17986.0      2  360.0  342
#
#        avggift  tcode   dob domain  target_d
# 152   8.571429      0  3001     U2      16.0
# 493  13.000000      0  3705     U4      20.0
# 581  85.000000      0  1602     C1     100.0

# %%
hlth1.iloc[[6, 35], 4:6] # muestra de las filas 6 i 35 las columnas de la 5 a la 6
# Out:
#       ic4  hvp1
# 6   419.0     5
# 35  531.0     5

# %%
hlth1.loc[[38, 90], "gender":"ic3"] #lo mismo que antes pero usando nombres
# Out:
#    gender  medianhv  ic1    ic4  hvp1  pcapinc  pobc1    ic2  ic3
# 38      F     878.0  310  588.0    30  22281.0      4  517.0  433
# 90      F     476.0  219  319.0     0  10966.0      1  280.0  272

# %%
hlth1.loc[[39, 95], ["gender","pcapinc"]] #mas de lo mismo pero solo 2 columnas
# Out:
#    gender  pcapinc
# 39      F  20971.0
# 95      M  10726.0

# %%
subhl = hlth1.iloc[[6, 35], 4:6]

# %%
hlth1[hlth1["gender"].str.match("unknown") | hlth1["gender"].str.match("J")] #prueba usando or para sacar gender unknone or J
# Out:
#            state   gender  medianhv   ic1     ic4  hvp1  pcapinc  pobc1  \
# 15            MI  unknown     890.0   463   523.0     1   9493.0      5
# 21            OK  unknown    1040.0   472   656.0     0  26962.0      2
# 22            AR  unknown     603.0   208   341.0     2  12038.0      1
# 44            AL        J     765.0   408   472.0     1  15150.0      1
# 54            CA  unknown    2143.0   280   373.0    63  12935.0     29
# 77          Cali  unknown    2016.0   431   497.0    51  17882.0     11
# 84            IL  unknown    1055.0   366   400.0     0  11289.0      8
# 94            FL  unknown     581.0   349   373.0     0   9667.0     19
# 108           NJ        J    1439.0   370   464.0     3  13353.0     15
# 130           FL  unknown    3542.0   642   843.0    76  53131.0      3
# 151           CA  unknown    3020.0   756   823.0    95  26135.0      4
# 186           IN  unknown     561.0   302   331.0     1  10873.0      0
# ...

# %%
healthfem = hlth1.query('gender == "F"')
healthfem = healthfem.iloc[[3,4], 2:6]

# %%
healthfem
# Out:
#     medianhv  ic1    ic4  hvp1
# 9      786.0  593  617.0    61
# 10    1569.0  673  781.0    22

# %%
hlth1["gender"].unique()
# Out:
# array(['M', 'F', 'female', 'Male', 'unknown', 'U', 'J', 'male', 'Female',
#        'feamale'], dtype=object)

# %% [raw]
# print(range(len(hlth1["gender"]))) #this is how i almost came up to resolve the reclasification of "gender"
#
# genderl1 = []
#
# for i in range(len(hlth1["gender"])):
#     #print(hlth1["gender"][i])
#     if (hlth1["gender"][i] == "M" or hlth1["gender"][i] == "Male" or hlth1["gender"][i] == "male"):
#         #print("male")
#         genderl1.append("male")
#     elif (hlth1["gender"][i] == "F" or hlth1["gender"][i] == "Female" or hlth1["gender"][i] == "female" or hlth1["gender"][i] == "feamale"):
#         #print("female")
#         genderl1.append("female")
#     else:
#         #print("unknown")
#         genderl1.append("unknown")

# %% [raw]
# genderl1

# %% [raw]
# genderr=[]
#
# for i in range(len(health1['gender'])):
#     if i == 'F' or 'female' or 'Female':
#         genderr.append('female')
#     elif i == 'M' or'Male' or 'male':
#         genderr.append('male')
#     else:
#         genderr.append('Unknown')

# %% [raw]
# hlth1["gender"] = genderr

# %% [raw]
# hlth1["gender"].unique()

# %% [raw]
# hlth1["gender"] = genderl1

# %% [raw]
# hlth1["gender"]

# %%
print(range(len(hlth1["gender"]))) #this is a clena code to do the same

genderl1 = []

for i in range(len(hlth1["gender"])):
    #print(hlth1["gender"][i])
    if hlth1["gender"][i] in ["male", "Male", "M"] :
        #print("male")
        genderl1.append("male")
    elif hlth1["gender"][i] in ["female", "Female", "F", "feamale" ] :
        #print("female")
        genderl1.append("female")
    else:
        #print("unknown")
        genderl1.append("unknown")
# Out:
# range(0, 1007)

# %%
genderl1
# Out:
# ['male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'female',
#  'unknown',
#  'female',
#  'female',
#  'female',
#  'unknown',
#  'female',
#  'unknown',
#  'unknown',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'unknown',
#  'male',
#  'female',
#  'unknown',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'male',
#  'unknown',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'female',
#  'female',
#  'unknown',
#  'female',
#  'female',
# ...

# %%
hlth1["gender"] = genderl1

# %%
hlth1["gender"].unique()
# Out:
# array(['male', 'female', 'unknown'], dtype=object)
