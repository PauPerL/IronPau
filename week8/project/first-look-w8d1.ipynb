# %%
import pandas as pd

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is EA54-6392
#
#  Directory of C:\Users\Krop\Documents\Ironhack\IronPau\week8\project
#
# 02/06/2022  10:25    <DIR>          .
# 02/06/2022  10:25    <DIR>          ..
# 02/06/2022  10:25    <DIR>          .ipynb_checkpoints
# 30/05/2022  18:10    <DIR>          Bacardi
# 30/05/2022  15:17       440,848,929 Bacardi-20220530T131548Z-001.zip
# 01/06/2022  19:41            78,330 first-look-w8d1.ipynb
# 02/06/2022  10:25           588,238 time_series_example_class-Copy1.ipynb
#                3 File(s)    441,515,497 bytes
#                4 Dir(s)  761,459,617,792 bytes free

# %%
cd bacardi\Files
# Out:
# C:\Users\Krop\Documents\Ironhack\IronPau\week8\project\bacardi\Files

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is EA54-6392
#
#  Directory of C:\Users\Krop\Documents\Ironhack\IronPau\week8\project\bacardi\Files
#
# 01/06/2022  16:33    <DIR>          .
# 01/06/2022  16:33    <DIR>          ..
# 03/05/2022  07:29        71,965,842 Digital_Commerce_Market Share US_UEBig5.xlsx
# 03/05/2022  06:54        10,276,231 Digital_Commerce_Pure Players_US_UEbig5.xlsb
# 09/05/2022  00:46        37,760,083 Digital_Commerce_RetailersCom_US_UEBig5.xlsx
# 01/06/2022  09:26        11,763,614 Market_share_clean_v2.xlsx
# 01/06/2022  15:55         3,267,508 pureRetailersCleanv1.csv
#                5 File(s)    135,033,278 bytes
#                2 Dir(s)  761,459,617,792 bytes free

# %%
#get the 3 df

# we get all the sheets of the data
dfmarketshare=pd.read_excel('Digital_Commerce_Market Share US_UEBig5.xlsx', sheet_name=[0,1,2])

dfcommerceret=pd.read_excel('Digital_Commerce_RetailersCom_US_UEBig5.xlsx',sheet_name=[0,1])

# %%
#we are interested on the dataframe [3]
dfpurep = pd.read_excel('Digital_Commerce_Pure Players_US_UEbig5.xlsb', sheet_name=[0,1,2,3,4], engine='pyxlsb')

# %% [markdown]
# ### explore marketshare

# %%
#this is a dictionary of df
dfmarketshare.keys()
# Out:
# dict_keys([0, 1, 2])

# %%
dfmarketshare[2].head()
# Out:
#   Budget Type Fiscal Year      Month Customer Name Customer Group 1  \
# 0      ACTUAL        FY22 2022-01-01        Drizly           Drizly
# 1      ACTUAL        FY22 2022-01-01        Drizly           Drizly
# 2      ACTUAL        FY22 2021-10-01        Drizly           Drizly
# 3      ACTUAL        FY22 2021-11-01        Drizly           Drizly
# 4      ACTUAL        FY21 2020-11-01        Drizly           Drizly
#
#   Customer Group 2 Financial Category Category               Brand  \
# 0           Drizly              OTHER    OTHER  8th Day Distillery
# 1           Drizly              OTHER    OTHER             Absente
# 2           Drizly              OTHER    OTHER             Absente
# 3           Drizly              OTHER    OTHER             Absente
# 4           Drizly              OTHER    OTHER             Absente
#
#                                         Brandline  ...  IPC Value Market  \
# 0  8th Day Chat Maison Absinthe Verte  - 37.50 CL  ...        NaN     US
# ...

# %%
# on this dict key:0 --> Ocado(UK) , key:1 --> Amazon(EU5), key:2 --> Drizly(USA)
dfmarketshare[1].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 403117 entries, 0 to 403116
# Data columns (total 25 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Budget Type         403117 non-null  object
#  1   Fiscal Year         403117 non-null  object
#  2   Month               403117 non-null  datetime64[ns]
#  3   Customer Name       403117 non-null  object
#  4   Customer Group 1    403117 non-null  object
#  5   Customer Group 2    403117 non-null  object
#  6   Financial Category  403117 non-null  object
#  7   Category            403117 non-null  object
#  8   Brand               403117 non-null  object
#  9   Brandline           403117 non-null  object
#  10  Format              402944 non-null  float64
#  11  Classification      403117 non-null  object
#  12  Geography           403117 non-null  object
#  13  Region              403117 non-null  object
#  14  Agency Toggle       403117 non-null  object
# ...

# %%
dfmarketshare[1]['Financial Category'].value_counts()
# Out:
# GIN                     55475
# LIQUEUR                 53529
# RUM                     53462
# WHISKY - MALTS          50387
# VODKA                   39756
# WHISKY - BLENDED        39721
# COGNAC                  34503
# SPARKLING               32569
# TEQUILA                 16178
# VERMOUTH                10954
# RTD/RTS                  9073
# CACHACA                  4266
# NON-ALCOHOLIC SPIRIT     3244
# Name: Financial Category, dtype: int64

# %%
dfmarketshare[1]['Category'].value_counts()
# Out:
# GIN                     55475
# LIQUEUR                 53529
# RUM                     53462
# WHISKY - MALTS          50387
# VODKA                   39756
# WHISKY - BLENDED        39721
# COGNAC                  34503
# SPARKLING               32569
# TEQUILA                 16178
# VERMOUTH                10954
# RTD/RTS                  9073
# CACHACA                  4266
# NON-ALCOHOLIC SPIRIT     3244
# Name: Category, dtype: int64

# %%
dfmarketshare[1]['Geography'].value_counts()
# Out:
# UK         141558
# Germany    111879
# Italy       65854
# Spain       44398
# France      39428
# Name: Geography, dtype: int64

# %%
dfmarketshare[1]['Market'].value_counts()
# Out:
# GB    141558
# DE    111879
# IT     65854
# ES     44398
# FR     39428
# Name: Market, dtype: int64

# %%
dfmarketshare[1]['Customer Group 1'].value_counts()
# Out:
# Amazon France           115610
# Amazon Germany          111879
# Amazon Italy             65854
# Amazon Great Britain     65376
# Amazon Spain             44398
# Name: Customer Group 1, dtype: int64

# %%
#clean_dfmarketshare=
dfmarketshare[1][['Fiscal Year','Month',]]

# %% [markdown]
# ### explore pure players

# %%
dfpurep.keys()
# Out:
# dict_keys([0, 1, 2, 3, 4])

# %%
dfpurep[3].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87244 entries, 0 to 87243
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Budget Type         87244 non-null  object
#  1   Fiscal Year         87244 non-null  object
#  2   Month               87244 non-null  int64
#  3   Customer Name       87244 non-null  object
#  4   Customer Group 1    87244 non-null  object
#  5   Customer Group 2    87244 non-null  object
#  6   Financial Category  87244 non-null  object
#  7   Category            87244 non-null  object
#  8   Brand               87244 non-null  object
#  9   Brandline           87244 non-null  object
#  10  Format              87243 non-null  float64
#  11  Classification      87244 non-null  object
#  12  Geography           87244 non-null  object
#  13  Region              87244 non-null  object
#  14  Agency Toggle       87244 non-null  object
# ...

# %%
# the data that we need is on key:3
dfpurep[3]
# Out:
#       Budget Type Fiscal Year  Month  Customer Name Customer Group 1  \
# 0          ACTUAL        FY20  43556    Reserve Bar      Reserve Bar
# 1          ACTUAL        FY20  43556    Reserve Bar      Reserve Bar
# 2          ACTUAL        FY20  43556    Reserve Bar      Reserve Bar
# 3          ACTUAL        FY20  43556    Reserve Bar      Reserve Bar
# 4          ACTUAL        FY20  43556    Reserve Bar      Reserve Bar
# ...           ...         ...    ...            ...              ...
# 87239      ACTUAL        FY21  44256  YOPOGOELHIELO    YOPOGOELHIELO
# 87240      ACTUAL        FY21  44256  YOPOGOELHIELO    YOPOGOELHIELO
# 87241      ACTUAL        FY21  44256  YOPOGOELHIELO    YOPOGOELHIELO
# 87242      ACTUAL        FY21  44256  YOPOGOELHIELO    YOPOGOELHIELO
# 87243      ACTUAL        FY21  44256  YOPOGOELHIELO    YOPOGOELHIELO
#
#       Customer Group 2 Financial Category          Category             Brand  \
# ...

# %%
dfpurep[3]['Geography'].value_counts()
# Out:
# United States    35251
# Germany          17873
# Italy            11526
# UK                8985
# France            8467
# Spain             5142
# Name: Geography, dtype: int64

# %%
dft=dfpurep[3][dfpurep[3]['Geography']<='United States']

# %%
dft=dft[dft['Geography']<='UK']

# %%
dft.reset_index(inplace=True)

# %%
dft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51993 entries, 0 to 51992
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               51993 non-null  int64
#  1   Budget Type         51993 non-null  object
#  2   Fiscal Year         51993 non-null  object
#  3   Month               51993 non-null  int64
#  4   Customer Name       51993 non-null  object
#  5   Customer Group 1    51993 non-null  object
#  6   Customer Group 2    51993 non-null  object
#  7   Financial Category  51993 non-null  object
#  8   Category            51993 non-null  object
#  9   Brand               51993 non-null  object
#  10  Brandline           51993 non-null  object
#  11  Format              51993 non-null  float64
#  12  Classification      51993 non-null  object
#  13  Geography           51993 non-null  object
#  14  Region              51993 non-null  object
# ...

# %%
dft=dft.drop(['Budget Type', 'Customer Group 2','Financial Category', 'Brandline', 
          'Classification', 'Region', 'Agency Toggle', 'IPC Value', '4 Digit Code', 'Currency', 'Manufacturer',
         'DataInd', 'DataSource'], axis=1)

# %%
dft
# Out:
#        index Fiscal Year  Month     Customer Name Customer Group 1  \
# 0      24221        FY20  43556  Amazon 1P France    Amazon France
# 1      24222        FY20  43556  Amazon 1P France    Amazon France
# 2      24223        FY20  43556  Amazon 1P France    Amazon France
# 3      24224        FY20  43556  Amazon 1P France    Amazon France
# 4      24225        FY20  43556  Amazon 1P France    Amazon France
# ...      ...         ...    ...               ...              ...
# 51988  87239        FY21  44256     YOPOGOELHIELO    YOPOGOELHIELO
# 51989  87240        FY21  44256     YOPOGOELHIELO    YOPOGOELHIELO
# 51990  87241        FY21  44256     YOPOGOELHIELO    YOPOGOELHIELO
# 51991  87242        FY21  44256     YOPOGOELHIELO    YOPOGOELHIELO
# 51992  87243        FY21  44256     YOPOGOELHIELO    YOPOGOELHIELO
#
#                Category             Brand  Format Geography Market    Vol 9LC
# 0             SPARKLING            AGENCY    75.0    France     FR  15.500000
# ...

# %%
dft.dropna(subset=['Vol 9LC'], inplace=True)

# %%
dft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48826 entries, 0 to 51992
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             48826 non-null  int64
#  1   Fiscal Year       48826 non-null  object
#  2   Month             48826 non-null  int64
#  3   Customer Name     48826 non-null  object
#  4   Customer Group 1  48826 non-null  object
#  5   Category          48826 non-null  object
#  6   Brand             48826 non-null  object
#  7   Format            48826 non-null  float64
#  8   Geography         48826 non-null  object
#  9   Market            48826 non-null  object
#  10  Vol 9LC           48826 non-null  float64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 4.5+ MB

# %%
dft.reset_index(inplace=True)

# %%
dft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48826 entries, 0 to 48825
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   level_0           48826 non-null  int64
#  1   index             48826 non-null  int64
#  2   Fiscal Year       48826 non-null  object
#  3   Month             48826 non-null  int64
#  4   Customer Name     48826 non-null  object
#  5   Customer Group 1  48826 non-null  object
#  6   Category          48826 non-null  object
#  7   Brand             48826 non-null  object
#  8   Format            48826 non-null  float64
#  9   Geography         48826 non-null  object
#  10  Market            48826 non-null  object
#  11  Vol 9LC           48826 non-null  float64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 4.5+ MB

# %%
dft
# Out:
#        level_0  index Fiscal Year  Month     Customer Name Customer Group 1  \
# 0            0  24221        FY20  43556  Amazon 1P France    Amazon France
# 1            1  24222        FY20  43556  Amazon 1P France    Amazon France
# 2            3  24224        FY20  43556  Amazon 1P France    Amazon France
# 3            5  24226        FY20  43556  Amazon 1P France    Amazon France
# 4            7  24228        FY20  43556  Amazon 1P France    Amazon France
# ...        ...    ...         ...    ...               ...              ...
# 48821    51988  87239        FY21  44256     YOPOGOELHIELO    YOPOGOELHIELO
# 48822    51989  87240        FY21  44256     YOPOGOELHIELO    YOPOGOELHIELO
# 48823    51990  87241        FY21  44256     YOPOGOELHIELO    YOPOGOELHIELO
# 48824    51991  87242        FY21  44256     YOPOGOELHIELO    YOPOGOELHIELO
# 48825    51992  87243        FY21  44256     YOPOGOELHIELO    YOPOGOELHIELO
#
# ...

# %%
dft=dft.drop(['level_0', 'index'], axis=1)

# %%
#als drop market
dft=dft.drop(['Market'], axis=1)

# %%
dft
# Out:
#       Fiscal Year  Month     Customer Name Customer Group 1          Category  \
# 0            FY20  43556  Amazon 1P France    Amazon France         SPARKLING
# 1            FY20  43556  Amazon 1P France    Amazon France         SPARKLING
# 2            FY20  43556  Amazon 1P France    Amazon France           CACHACA
# 3            FY20  43556  Amazon 1P France    Amazon France            COGNAC
# 4            FY20  43556  Amazon 1P France    Amazon France               GIN
# ...           ...    ...               ...              ...               ...
# 48821        FY21  44256     YOPOGOELHIELO    YOPOGOELHIELO          VERMOUTH
# 48822        FY21  44256     YOPOGOELHIELO    YOPOGOELHIELO             VODKA
# 48823        FY21  44256     YOPOGOELHIELO    YOPOGOELHIELO  WHISKY - Blended
# 48824        FY21  44256     YOPOGOELHIELO    YOPOGOELHIELO  WHISKY - Blended
# 48825        FY21  44256     YOPOGOELHIELO    YOPOGOELHIELO  WHISKY - Blended
#
# ...

# %% [raw]
# dft['Vol 9LC'].nunique()

# %%
print(dft['Geography'].value_counts())
# Out:
# Germany    17085
# Italy      11227
# UK          8112
# France      7405
# Spain       4997
# Name: Geography, dtype: int64

# %%
dft['Geography'].unique()
# Out:
# array(['France', 'Germany', 'UK', 'Italy', 'Spain'], dtype=object)

# %%
dft = dft[dft['Geography']!='UK']

# %%
dft['Geography'].unique()
# Out:
# array(['France', 'Germany', 'Italy', 'Spain'], dtype=object)

# %%
dft.to_csv('pureRetailersCleanv1.csv')

# %%
dft
# Out:
#       Fiscal Year  Month     Customer Name Customer Group 1          Category  \
# 0            FY20  43556  Amazon 1P France    Amazon France         SPARKLING
# 1            FY20  43556  Amazon 1P France    Amazon France         SPARKLING
# 2            FY20  43556  Amazon 1P France    Amazon France           CACHACA
# 3            FY20  43556  Amazon 1P France    Amazon France            COGNAC
# 4            FY20  43556  Amazon 1P France    Amazon France               GIN
# ...           ...    ...               ...              ...               ...
# 48821        FY21  44256     YOPOGOELHIELO    YOPOGOELHIELO          VERMOUTH
# 48822        FY21  44256     YOPOGOELHIELO    YOPOGOELHIELO             VODKA
# 48823        FY21  44256     YOPOGOELHIELO    YOPOGOELHIELO  WHISKY - Blended
# 48824        FY21  44256     YOPOGOELHIELO    YOPOGOELHIELO  WHISKY - Blended
# 48825        FY21  44256     YOPOGOELHIELO    YOPOGOELHIELO  WHISKY - Blended
#
# ...

# %%
templ=dft['Vol 9LC'].unique()

# %%
templ
# Out:
# array([15.5     ,  1.5     ,  0.466667, ...,  3.6554  ,  4.1223  ,
#        15.166667])

# %%
dft.groupby(['Geography']).size()
# Out:
# Geography
# France      7405
# Germany    17085
# Italy      11227
# Spain       4997
# dtype: int64

# %%
dft.groupby(['Geography','Category']).size()
# Out:
# Geography  Category
# France     CACHACA               81
#            COGNAC               171
#            GIN                  770
#            LIQUEUR              839
#            MULTIBRAND             5
#            NON-ALCOHOLIC        126
#            RTD/RTS              240
#            RUM                 1024
#            SPARKLING            575
#            TEQUILA              399
#            VERMOUTH             960
#            VODKA               1071
#            WHISKY - Blended     474
#            WHISKY - Malts       670
# Germany    CACHACA              114
#            COGNAC               327
#            GIN                 2019
#            LIQUEUR              692
#            MULTIBRAND            73
#            NON-ALCOHOLIC        433
#            RTD/RTS              592
#            RUM                 4817
#            SPARKLING            515
#            TEQUILA             1028
#            VERMOUTH            2597
# ...

# %%
dft.groupby(['Category']).size()
# Out:
# Category
# CACHACA              290
# COGNAC               632
# GIN                 5223
# LIQUEUR             2458
# MULTIBRAND            79
# NON-ALCOHOLIC        696
# RTD/RTS             1752
# RUM                 8032
# SPARKLING           1807
# TEQUILA             2468
# VERMOUTH            6334
# VODKA               3798
# WHISKY - Blended    2431
# WHISKY - Malts      4714
# dtype: int64
